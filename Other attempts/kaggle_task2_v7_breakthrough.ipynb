# %%
# ========================================================================
# BREAKTHROUGH TO 0.65+ PIPELINE
# Problem: Adding more models isn't helping (0.6385 → 0.6370)
# Solution: Focus on feature quality + truly diverse models
# ========================================================================

import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler

import lightgbm as lgb
from catboost import CatBoostClassifier
import xgboost as xgb

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

print("=" * 80)
print("BREAKTHROUGH PIPELINE - QUALITY OVER QUANTITY")
print("Focus: Better features + Model diversity + Smart ensembling")
print("=" * 80)
# Out:
# ================================================================================
# BREAKTHROUGH PIPELINE - QUALITY OVER QUANTITY
# Focus: Better features + Model diversity + Smart ensembling
# ================================================================================

# %%
# ========================================================================
# STEP 1: LOAD DATA
# ========================================================================
train = pd.read_csv('train1.csv')
test = pd.read_csv('test.csv')

TARGET = 'target'
ID_COL = 'id'

print(f"\nData loaded: {train.shape[0]} train, {test.shape[0]} test")
print(f"Class balance: {train[TARGET].value_counts(normalize=True).to_dict()}")
# Out:
# Data loaded: 296209 train, 126948 test
# Class balance: {0: 0.948732145208282, 1: 0.05126785479171801}

# %%
# ========================================================================
# STEP 2: INTELLIGENT FEATURE ENGINEERING
# ========================================================================
print("\n" + "=" * 80)
print("STEP 2: INTELLIGENT FEATURE ENGINEERING")
print("=" * 80)

def create_breakthrough_features(df, is_train=True):
    """
    Focus on high-quality, insurance-domain features
    """
    df = df.copy()
    
    print("  Creating domain-specific features...")
    
    # === Risk Profiling Features ===
    
    # 1. Total risk indicators
    risk_cols = [c for c in df.columns if c.startswith('ps_ind_')]
    if risk_cols:
        df['total_ind_features'] = df[risk_cols].sum(axis=1)
        df['avg_ind_features'] = df[risk_cols].mean(axis=1)
        df['nonzero_ind_count'] = (df[risk_cols] != 0).sum(axis=1)
    
    # 2. Car-related risk
    car_cols = [c for c in df.columns if c.startswith('ps_car_')]
    if car_cols:
        df['total_car_features'] = df[car_cols].sum(axis=1)
        df['car_missing_count'] = df[car_cols].isnull().sum(axis=1)
    
    # 3. Registration quality
    if all(c in df.columns for c in ['ps_reg_01', 'ps_reg_02', 'ps_reg_03']):
        df['reg_total'] = df['ps_reg_01'] + df['ps_reg_02'] + df['ps_reg_03']
        df['reg_product'] = df['ps_reg_01'] * df['ps_reg_02'] * df['ps_reg_03']
        df['reg_std'] = df[['ps_reg_01', 'ps_reg_02', 'ps_reg_03']].std(axis=1)
    
    # === Key Interactions (insurance domain) ===
    
    # Driver profile x Car value
    if 'ps_ind_15' in df.columns and 'ps_car_13' in df.columns:
        df['driver_car_interaction'] = df['ps_ind_15'] * df['ps_car_13']
        df['driver_car_ratio'] = df['ps_ind_15'] / (df['ps_car_13'] + 1)
    
    # Car age x Region risk
    if 'ps_car_15' in df.columns and 'ps_reg_03' in df.columns:
        df['car_age_region'] = df['ps_car_15'] * df['ps_reg_03']
    
    # Binary risk flags combined
    bin_cols = [c for c in df.columns if c.endswith('_bin')]
    if len(bin_cols) >= 3:
        # Create risk score from binary features
        df['binary_risk_score'] = df[bin_cols].sum(axis=1)
        df['binary_risk_pct'] = df['binary_risk_score'] / len(bin_cols)
    
    # === Statistical features ===
    
    # Data completeness (important for insurance)
    df['completeness_score'] = df.notna().sum(axis=1) / len(df.columns)
    
    # Calculated features analysis
    calc_cols = [c for c in df.columns if c.startswith('ps_calc_')]
    if calc_cols:
        df['calc_sum'] = df[calc_cols].sum(axis=1)
        df['calc_max'] = df[calc_cols].max(axis=1)
        df['calc_min'] = df[calc_cols].min(axis=1)
        df['calc_range'] = df['calc_max'] - df['calc_min']
    
    # === Categorical transformations ===
    
    # High cardinality categoricals
    if 'ps_car_11_cat' in df.columns:
        df['ps_car_11_cat_freq'] = df.groupby('ps_car_11_cat')['ps_car_11_cat'].transform('count')
    
    return df

print("Applying to train...")
train_fe = create_breakthrough_features(train, is_train=True)

print("Applying to test...")
test_fe = create_breakthrough_features(test, is_train=False)
# Out:
# ================================================================================
# STEP 2: INTELLIGENT FEATURE ENGINEERING
# ================================================================================
# Applying to train...
#   Creating domain-specific features...
# Applying to test...
#   Creating domain-specific features...

# %%
# ========================================================================
# STEP 3: SMART FEATURE SELECTION
# ========================================================================
print("\n" + "=" * 80)
print("STEP 3: SMART FEATURE SELECTION")
print("=" * 80)

X_full = train_fe.drop([TARGET, ID_COL], axis=1)
y_full = train_fe[TARGET]
test_full = test_fe.drop([ID_COL], axis=1, errors='ignore')

# Align
common_features = list(set(X_full.columns) & set(test_full.columns))
X_full = X_full[common_features]
test_full = test_full[common_features]

# Fill missing
X_full = X_full.fillna(-999)
test_full = test_full.fillna(-999)

print(f"Total features: {X_full.shape[1]}")

# Use BOTH LightGBM and permutation importance
print("\nCalculating feature importance (LightGBM)...")
selector = lgb.LGBMClassifier(n_estimators=200, random_state=RANDOM_SEED, verbose=-1, class_weight='balanced')
selector.fit(X_full, y_full)

importance_df = pd.DataFrame({
    'feature': X_full.columns,
    'importance': selector.feature_importances_
}).sort_values('importance', ascending=False)

# Remove zero-importance features
zero_importance = importance_df[importance_df['importance'] == 0]['feature'].tolist()
if zero_importance:
    print(f"Removing {len(zero_importance)} zero-importance features")
    X_full = X_full.drop(zero_importance, axis=1)
    test_full = test_full.drop(zero_importance, axis=1)

# Keep top features
N_FEATURES = min(80, len(X_full.columns))
selected_features = importance_df.head(N_FEATURES)['feature'].tolist()
selected_features = [f for f in selected_features if f in X_full.columns]

X_full = X_full[selected_features]
test_full = test_full[selected_features]

print(f"Selected {len(selected_features)} features")
print("\nTop 15 features:")
for i, row in importance_df.head(15).iterrows():
    print(f"  {row['feature']:30s}: {row['importance']:.1f}")
# Out:
# ================================================================================
# STEP 3: SMART FEATURE SELECTION
# ================================================================================
# Total features: 84
#
# Calculating feature importance (LightGBM)...
#   File "C:\Users\SHEIKHANI LAPTOP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\externals\loky\backend\context.py", line 247, in _count_physical_cores
#     cpu_count_physical = _count_physical_cores_win32()
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\SHEIKHANI LAPTOP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\externals\loky\backend\context.py", line 299, in _count_physical_cores_win32
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Removing 7 zero-importance features
# Selected 77 features
#
# Top 15 features:
#   calc_sum                      : 267.0
#   driver_car_ratio              : 250.0
#   ps_car_13                     : 237.0
#   feature6                      : 231.0
#   reg_std                       : 211.0
#   feature7                      : 209.0
#   ps_ind_03                     : 205.0
#   total_car_features            : 190.0
#   driver_car_interaction        : 186.0
#   ps_car_14                     : 186.0
#   feature2                      : 170.0
#   feature4                      : 159.0
#   car_age_region                : 141.0
#   ps_reg_03                     : 131.0
#   avg_ind_features              : 125.0

# %%
# ========================================================================
# STEP 4: AGGRESSIVE TARGET ENCODING (PROPERLY)
# ========================================================================
print("\n" + "=" * 80)
print("STEP 4: PROPER TARGET ENCODING")
print("=" * 80)

def aggressive_target_encoding(X_train, y_train, X_test, alpha=15):
    """
    Target encode ALL categorical features with proper CV
    """
    X_train_te = X_train.copy()
    X_test_te = X_test.copy()
    
    # Identify categorical columns
    cat_cols = [col for col in X_train.columns 
                if col.endswith('_cat') or X_train[col].nunique() < 50]
    
    print(f"Target encoding {len(cat_cols)} categorical features...")
    
    global_mean = y_train.mean()
    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=RANDOM_SEED)
    
    for col in cat_cols:
        if col not in X_train.columns:
            continue
        
        X_train_te[f'{col}_te'] = global_mean
        
        # CV encoding for train
        for train_idx, val_idx in kf.split(X_train, y_train):
            X_tr = X_train.iloc[train_idx]
            y_tr = y_train.iloc[train_idx]
            X_vl = X_train.iloc[val_idx]
            
            # Calculate encoding
            encoding = y_tr.groupby(X_tr[col]).agg(['mean', 'count'])
            smoothed = (encoding['count'] * encoding['mean'] + alpha * global_mean) / (encoding['count'] + alpha)
            
            X_train_te.loc[X_train.index[val_idx], f'{col}_te'] = X_vl[col].map(smoothed).fillna(global_mean).values
        
        # Full train for test
        encoding_full = y_train.groupby(X_train[col]).agg(['mean', 'count'])
        smoothed_full = (encoding_full['count'] * encoding_full['mean'] + alpha * global_mean) / (encoding_full['count'] + alpha)
        
        X_test_te[f'{col}_te'] = X_test[col].map(smoothed_full).fillna(global_mean)
    
    return X_train_te, X_test_te

X_full, test_full = aggressive_target_encoding(X_full, y_full, test_full, alpha=15)

print(f"Final feature count: {X_full.shape[1]}")
# Out:
# ================================================================================
# STEP 4: PROPER TARGET ENCODING
# ================================================================================
# Target encoding 58 categorical features...
# Final feature count: 135

# %%
# ========================================================================
# STEP 5: TRAIN PROPERLY TUNED MODELS WITH 10-FOLD CV
# ========================================================================
print("\n" + "=" * 80)
print("STEP 5: TRAINING OPTIMIZED MODELS (10-FOLD CV)")
print("=" * 80)

kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=RANDOM_SEED)

# Model 1: CatBoost (your best)
print("\n1️⃣  CatBoost (optimized)...")
oof_cat = np.zeros(len(X_full))
test_cat = np.zeros(len(test_full))

for fold, (train_idx, val_idx) in enumerate(kfold.split(X_full, y_full)):
    X_tr, X_vl = X_full.iloc[train_idx], X_full.iloc[val_idx]
    y_tr, y_vl = y_full.iloc[train_idx], y_full.iloc[val_idx]
    
    model = CatBoostClassifier(
        iterations=800,
        depth=5,
        learning_rate=0.025,
        l2_leaf_reg=8,
        random_strength=1.5,
        bagging_temperature=0.7,
        border_count=128,
        auto_class_weights='Balanced',
        random_state=RANDOM_SEED + fold,
        verbose=0
    )
    
    model.fit(X_tr, y_tr, eval_set=(X_vl, y_vl), early_stopping_rounds=50, verbose=False)
    
    oof_cat[val_idx] = model.predict_proba(X_vl)[:, 1]
    test_cat += model.predict_proba(test_full)[:, 1] / 10

auc_cat = roc_auc_score(y_full, oof_cat)
print(f"   OOF AUROC: {auc_cat:.4f}")

# Model 2: LightGBM (dart mode for diversity)
print("\n2️⃣  LightGBM (DART boosting)...")
oof_lgb = np.zeros(len(X_full))
test_lgb = np.zeros(len(test_full))

for fold, (train_idx, val_idx) in enumerate(kfold.split(X_full, y_full)):
    X_tr, X_vl = X_full.iloc[train_idx], X_full.iloc[val_idx]
    y_tr, y_vl = y_full.iloc[train_idx], y_full.iloc[val_idx]
    
    model = lgb.LGBMClassifier(
        boosting_type='dart',  # Different from default gbdt
        n_estimators=800,
        num_leaves=48,
        learning_rate=0.025,
        min_child_samples=35,
        subsample=0.85,
        colsample_bytree=0.85,
        reg_alpha=0.3,
        reg_lambda=0.3,
        class_weight='balanced',
        random_state=RANDOM_SEED + fold,
        verbose=-1
    )
    
    model.fit(X_tr, y_tr, eval_set=[(X_vl, y_vl)],
              callbacks=[lgb.early_stopping(50), lgb.log_evaluation(0)])
    
    oof_lgb[val_idx] = model.predict_proba(X_vl)[:, 1]
    test_lgb += model.predict_proba(test_full)[:, 1] / 10

auc_lgb = roc_auc_score(y_full, oof_lgb)
print(f"   OOF AUROC: {auc_lgb:.4f}")

# Model 3: XGBoost (regularized)
print("\n3️⃣  XGBoost (heavily regularized)...")
oof_xgb = np.zeros(len(X_full))
test_xgb = np.zeros(len(test_full))

scale_pos_weight = (y_full == 0).sum() / (y_full == 1).sum()

for fold, (train_idx, val_idx) in enumerate(kfold.split(X_full, y_full)):
    X_tr, X_vl = X_full.iloc[train_idx], X_full.iloc[val_idx]
    y_tr, y_vl = y_full.iloc[train_idx], y_full.iloc[val_idx]
    
    model = xgb.XGBClassifier(
        n_estimators=800,
        max_depth=4,
        learning_rate=0.025,
        min_child_weight=6,
        subsample=0.85,
        colsample_bytree=0.85,
        gamma=1.5,
        reg_alpha=0.5,
        reg_lambda=0.5,
        scale_pos_weight=scale_pos_weight,
        random_state=RANDOM_SEED + fold
    )
    
    model.fit(X_tr, y_tr, eval_set=[(X_vl, y_vl)])
    
    oof_xgb[val_idx] = model.predict_proba(X_vl)[:, 1]
    test_xgb += model.predict_proba(test_full)[:, 1] / 10

auc_xgb = roc_auc_score(y_full, oof_xgb)
print(f"   OOF AUROC: {auc_xgb:.4f}")

# Model 4: LightGBM (gbdt with different params)
print("\n4️⃣  LightGBM (GBDT variant)...")
oof_lgb2 = np.zeros(len(X_full))
test_lgb2 = np.zeros(len(test_full))

for fold, (train_idx, val_idx) in enumerate(kfold.split(X_full, y_full)):
    X_tr, X_vl = X_full.iloc[train_idx], X_full.iloc[val_idx]
    y_tr, y_vl = y_full.iloc[train_idx], y_full.iloc[val_idx]
    
    model = lgb.LGBMClassifier(
        boosting_type='gbdt',
        n_estimators=800,
        num_leaves=64,
        learning_rate=0.02,
        min_child_samples=50,
        subsample=0.75,
        colsample_bytree=0.75,
        reg_alpha=1.0,
        reg_lambda=1.0,
        class_weight='balanced',
        random_state=RANDOM_SEED + fold + 100,
        verbose=-1
    )
    
    model.fit(X_tr, y_tr, eval_set=[(X_vl, y_vl)],
              callbacks=[lgb.early_stopping(50), lgb.log_evaluation(0)])
    
    oof_lgb2[val_idx] = model.predict_proba(X_vl)[:, 1]
    test_lgb2 += model.predict_proba(test_full)[:, 1] / 10

auc_lgb2 = roc_auc_score(y_full, oof_lgb2)
print(f"   OOF AUROC: {auc_lgb2:.4f}")
# Out:
# ================================================================================
# STEP 5: TRAINING OPTIMIZED MODELS (10-FOLD CV)
# ================================================================================
#
# 1️⃣  CatBoost (optimized)...
#    OOF AUROC: 0.6384
#
# 2️⃣  LightGBM (DART boosting)...
#    OOF AUROC: 0.6368
#
# 3️⃣  XGBoost (heavily regularized)...
# [0]	validation_0-logloss:0.69222
# [1]	validation_0-logloss:0.69128
# [2]	validation_0-logloss:0.69052
# [3]	validation_0-logloss:0.68964
# [4]	validation_0-logloss:0.68888
# [5]	validation_0-logloss:0.68816
# [6]	validation_0-logloss:0.68744
# [7]	validation_0-logloss:0.68672
# [8]	validation_0-logloss:0.68597
# [9]	validation_0-logloss:0.68529
# [10]	validation_0-logloss:0.68467
# [11]	validation_0-logloss:0.68397
# [12]	validation_0-logloss:0.68341
# [13]	validation_0-logloss:0.68272
# [14]	validation_0-logloss:0.68226
# [15]	validation_0-logloss:0.68168
# [16]	validation_0-logloss:0.68112
# [17]	validation_0-logloss:0.68070
# [18]	validation_0-logloss:0.68019
# [19]	validation_0-logloss:0.67935
# [20]	validation_0-logloss:0.67882
# [21]	validation_0-logloss:0.67836
# [22]	validation_0-logloss:0.67801
# [23]	validation_0-logloss:0.67752
# [24]	validation_0-logloss:0.67700
# [25]	validation_0-logloss:0.67652
# [26]	validation_0-logloss:0.67605
# [27]	validation_0-logloss:0.67560
# [28]	validation_0-logloss:0.67511
# [29]	validation_0-logloss:0.67469
# [30]	validation_0-logloss:0.67428
# [31]	validation_0-logloss:0.67401
# [32]	validation_0-logloss:0.67352
# [33]	validation_0-logloss:0.67314
# [34]	validation_0-logloss:0.67277
# [35]	validation_0-logloss:0.67239
# [36]	validation_0-logloss:0.67215
# [37]	validation_0-logloss:0.67174
# [38]	validation_0-logloss:0.67137
# [39]	validation_0-logloss:0.67084
# [40]	validation_0-logloss:0.67045
# [41]	validation_0-logloss:0.67018
# [42]	validation_0-logloss:0.66991
# [43]	validation_0-logloss:0.66966
# [44]	validation_0-logloss:0.66939
# [45]	validation_0-logloss:0.66919
# [46]	validation_0-logloss:0.66891
# [47]	validation_0-logloss:0.66854
# [48]	validation_0-logloss:0.66822
# [49]	validation_0-logloss:0.66805
# [50]	validation_0-logloss:0.66773
# [51]	validation_0-logloss:0.66752
# [52]	validation_0-logloss:0.66739
# [53]	validation_0-logloss:0.66732
# [54]	validation_0-logloss:0.66718
# [55]	validation_0-logloss:0.66689
# [56]	validation_0-logloss:0.66665
# [57]	validation_0-logloss:0.66644
# [58]	validation_0-logloss:0.66610
# [59]	validation_0-logloss:0.66590
# [60]	validation_0-logloss:0.66570
# [61]	validation_0-logloss:0.66551
# [62]	validation_0-logloss:0.66528
# [63]	validation_0-logloss:0.66518
# [64]	validation_0-logloss:0.66496
# [65]	validation_0-logloss:0.66469
# [66]	validation_0-logloss:0.66430
# [67]	validation_0-logloss:0.66419
# [68]	validation_0-logloss:0.66411
# [69]	validation_0-logloss:0.66390
# [70]	validation_0-logloss:0.66350
# [71]	validation_0-logloss:0.66326
# [72]	validation_0-logloss:0.66311
# [73]	validation_0-logloss:0.66306
# [74]	validation_0-logloss:0.66289
# [75]	validation_0-logloss:0.66297
# [76]	validation_0-logloss:0.66291
# [77]	validation_0-logloss:0.66266
# [78]	validation_0-logloss:0.66253
# [79]	validation_0-logloss:0.66245
# [80]	validation_0-logloss:0.66226
# [81]	validation_0-logloss:0.66216
# [82]	validation_0-logloss:0.66208
# [83]	validation_0-logloss:0.66198
# [84]	validation_0-logloss:0.66194
# [85]	validation_0-logloss:0.66177
# [86]	validation_0-logloss:0.66177
# [87]	validation_0-logloss:0.66164
# [88]	validation_0-logloss:0.66164
# [89]	validation_0-logloss:0.66163
# [90]	validation_0-logloss:0.66147
# [91]	validation_0-logloss:0.66136
# [92]	validation_0-logloss:0.66129
# [93]	validation_0-logloss:0.66116
# [94]	validation_0-logloss:0.66103
# [95]	validation_0-logloss:0.66098
# [96]	validation_0-logloss:0.66074
# [97]	validation_0-logloss:0.66052
# [98]	validation_0-logloss:0.66035
# [99]	validation_0-logloss:0.66021
# [100]	validation_0-logloss:0.66002
# [101]	validation_0-logloss:0.66012
# [102]	validation_0-logloss:0.66008
# [103]	validation_0-logloss:0.65982
# [104]	validation_0-logloss:0.65975
# [105]	validation_0-logloss:0.65954
# [106]	validation_0-logloss:0.65951
# [107]	validation_0-logloss:0.65949
# [108]	validation_0-logloss:0.65946
# [109]	validation_0-logloss:0.65926
# [110]	validation_0-logloss:0.65929
# [111]	validation_0-logloss:0.65895
# [112]	validation_0-logloss:0.65885
# [113]	validation_0-logloss:0.65877
# [114]	validation_0-logloss:0.65862
# [115]	validation_0-logloss:0.65857
# [116]	validation_0-logloss:0.65841
# [117]	validation_0-logloss:0.65829
# [118]	validation_0-logloss:0.65815
# [119]	validation_0-logloss:0.65804
# [120]	validation_0-logloss:0.65804
# [121]	validation_0-logloss:0.65784
# [122]	validation_0-logloss:0.65767
# [123]	validation_0-logloss:0.65771
# [124]	validation_0-logloss:0.65769
# [125]	validation_0-logloss:0.65764
# [126]	validation_0-logloss:0.65759
# [127]	validation_0-logloss:0.65747
# [128]	validation_0-logloss:0.65751
# [129]	validation_0-logloss:0.65746
# [130]	validation_0-logloss:0.65761
# [131]	validation_0-logloss:0.65760
# [132]	validation_0-logloss:0.65742
# [133]	validation_0-logloss:0.65730
# [134]	validation_0-logloss:0.65725
# [135]	validation_0-logloss:0.65719
# [136]	validation_0-logloss:0.65706
# [137]	validation_0-logloss:0.65689
# [138]	validation_0-logloss:0.65687
# [139]	validation_0-logloss:0.65688
# [140]	validation_0-logloss:0.65701
# [141]	validation_0-logloss:0.65702
# [142]	validation_0-logloss:0.65696
# [143]	validation_0-logloss:0.65694
# [144]	validation_0-logloss:0.65704
# [145]	validation_0-logloss:0.65700
# [146]	validation_0-logloss:0.65704
# [147]	validation_0-logloss:0.65692
# [148]	validation_0-logloss:0.65682
# [149]	validation_0-logloss:0.65674
# [150]	validation_0-logloss:0.65676
# [151]	validation_0-logloss:0.65669
# [152]	validation_0-logloss:0.65664
# [153]	validation_0-logloss:0.65658
# [154]	validation_0-logloss:0.65653
# [155]	validation_0-logloss:0.65672
# [156]	validation_0-logloss:0.65668
# [157]	validation_0-logloss:0.65670
# [158]	validation_0-logloss:0.65677
# [159]	validation_0-logloss:0.65703
# [160]	validation_0-logloss:0.65699
# [161]	validation_0-logloss:0.65705
# [162]	validation_0-logloss:0.65710
# [163]	validation_0-logloss:0.65705
# [164]	validation_0-logloss:0.65707
# [165]	validation_0-logloss:0.65697
# [166]	validation_0-logloss:0.65695
# [167]	validation_0-logloss:0.65712
# [168]	validation_0-logloss:0.65690
# [169]	validation_0-logloss:0.65674
# [170]	validation_0-logloss:0.65668
# [171]	validation_0-logloss:0.65672
# [172]	validation_0-logloss:0.65661
# [173]	validation_0-logloss:0.65645
# [174]	validation_0-logloss:0.65630
# [175]	validation_0-logloss:0.65635
# [176]	validation_0-logloss:0.65625
# [177]	validation_0-logloss:0.65620
# [178]	validation_0-logloss:0.65583
# [179]	validation_0-logloss:0.65579
# [180]	validation_0-logloss:0.65571
# [181]	validation_0-logloss:0.65535
# [182]	validation_0-logloss:0.65510
# [183]	validation_0-logloss:0.65520
# [184]	validation_0-logloss:0.65508
# [185]	validation_0-logloss:0.65505
# [186]	validation_0-logloss:0.65505
# [187]	validation_0-logloss:0.65490
# [188]	validation_0-logloss:0.65486
# [189]	validation_0-logloss:0.65456
# [190]	validation_0-logloss:0.65452
# [191]	validation_0-logloss:0.65469
# [192]	validation_0-logloss:0.65460
# [193]	validation_0-logloss:0.65468
# [194]	validation_0-logloss:0.65480
# [195]	validation_0-logloss:0.65467
# [196]	validation_0-logloss:0.65441
# [197]	validation_0-logloss:0.65436
# [198]	validation_0-logloss:0.65419
# [199]	validation_0-logloss:0.65419
# [200]	validation_0-logloss:0.65412
# [201]	validation_0-logloss:0.65422
# [202]	validation_0-logloss:0.65423
# [203]	validation_0-logloss:0.65403
# [204]	validation_0-logloss:0.65394
# [205]	validation_0-logloss:0.65380
# [206]	validation_0-logloss:0.65373
# [207]	validation_0-logloss:0.65364
# [208]	validation_0-logloss:0.65360
# [209]	validation_0-logloss:0.65386
# [210]	validation_0-logloss:0.65371
# [211]	validation_0-logloss:0.65389
# [212]	validation_0-logloss:0.65382
# [213]	validation_0-logloss:0.65355
# [214]	validation_0-logloss:0.65382
# [215]	validation_0-logloss:0.65377
# [216]	validation_0-logloss:0.65362
# [217]	validation_0-logloss:0.65371
# [218]	validation_0-logloss:0.65400
# [219]	validation_0-logloss:0.65332
# [220]	validation_0-logloss:0.65342
# [221]	validation_0-logloss:0.65311
# [222]	validation_0-logloss:0.65314
# [223]	validation_0-logloss:0.65348
# [224]	validation_0-logloss:0.65367
# [225]	validation_0-logloss:0.65365
# [226]	validation_0-logloss:0.65365
# [227]	validation_0-logloss:0.65388
# [228]	validation_0-logloss:0.65316
# [229]	validation_0-logloss:0.65310
# [230]	validation_0-logloss:0.65305
# [231]	validation_0-logloss:0.65313
# [232]	validation_0-logloss:0.65298
# [233]	validation_0-logloss:0.65327
# [234]	validation_0-logloss:0.65316
# [235]	validation_0-logloss:0.65314
# [236]	validation_0-logloss:0.65304
# [237]	validation_0-logloss:0.65301
# [238]	validation_0-logloss:0.65303
# [239]	validation_0-logloss:0.65291
# [240]	validation_0-logloss:0.65298
# [241]	validation_0-logloss:0.65309
# [242]	validation_0-logloss:0.65281
# [243]	validation_0-logloss:0.65278
# [244]	validation_0-logloss:0.65279
# [245]	validation_0-logloss:0.65286
# [246]	validation_0-logloss:0.65277
# [247]	validation_0-logloss:0.65297
# [248]	validation_0-logloss:0.65293
# [249]	validation_0-logloss:0.65296
# [250]	validation_0-logloss:0.65275
# [251]	validation_0-logloss:0.65269
# [252]	validation_0-logloss:0.65268
# [253]	validation_0-logloss:0.65248
# [254]	validation_0-logloss:0.65234
# [255]	validation_0-logloss:0.65241
# [256]	validation_0-logloss:0.65244
# [257]	validation_0-logloss:0.65253
# [258]	validation_0-logloss:0.65291
# [259]	validation_0-logloss:0.65299
# [260]	validation_0-logloss:0.65286
# [261]	validation_0-logloss:0.65276
# [262]	validation_0-logloss:0.65297
# [263]	validation_0-logloss:0.65290
# [264]	validation_0-logloss:0.65316
# [265]	validation_0-logloss:0.65298
# [266]	validation_0-logloss:0.65276
# [267]	validation_0-logloss:0.65265
# [268]	validation_0-logloss:0.65268
# [269]	validation_0-logloss:0.65270
# [270]	validation_0-logloss:0.65301
# [271]	validation_0-logloss:0.65305
# [272]	validation_0-logloss:0.65310
# [273]	validation_0-logloss:0.65300
# [274]	validation_0-logloss:0.65280
# [275]	validation_0-logloss:0.65282
# [276]	validation_0-logloss:0.65281
# [277]	validation_0-logloss:0.65296
# [278]	validation_0-logloss:0.65296
# [279]	validation_0-logloss:0.65283
# [280]	validation_0-logloss:0.65298
# [281]	validation_0-logloss:0.65254
# [282]	validation_0-logloss:0.65251
# [283]	validation_0-logloss:0.65229
# [284]	validation_0-logloss:0.65237
# [285]	validation_0-logloss:0.65240
# [286]	validation_0-logloss:0.65248
# [287]	validation_0-logloss:0.65265
# [288]	validation_0-logloss:0.65270
# [289]	validation_0-logloss:0.65267
# [290]	validation_0-logloss:0.65266
# [291]	validation_0-logloss:0.65261
# [292]	validation_0-logloss:0.65239
# [293]	validation_0-logloss:0.65264
# [294]	validation_0-logloss:0.65274
# [295]	validation_0-logloss:0.65270
# [296]	validation_0-logloss:0.65263
# [297]	validation_0-logloss:0.65272
# [298]	validation_0-logloss:0.65279
# [299]	validation_0-logloss:0.65268
# [300]	validation_0-logloss:0.65288
# [301]	validation_0-logloss:0.65296
# [302]	validation_0-logloss:0.65266
# [303]	validation_0-logloss:0.65277
# [304]	validation_0-logloss:0.65280
# [305]	validation_0-logloss:0.65306
# [306]	validation_0-logloss:0.65298
# [307]	validation_0-logloss:0.65307
# [308]	validation_0-logloss:0.65310
# [309]	validation_0-logloss:0.65295
# [310]	validation_0-logloss:0.65305
# [311]	validation_0-logloss:0.65298
# [312]	validation_0-logloss:0.65306
# [313]	validation_0-logloss:0.65340
# [314]	validation_0-logloss:0.65339
# [315]	validation_0-logloss:0.65345
# [316]	validation_0-logloss:0.65351
# [317]	validation_0-logloss:0.65334
# [318]	validation_0-logloss:0.65304
# [319]	validation_0-logloss:0.65300
# [320]	validation_0-logloss:0.65301
# [321]	validation_0-logloss:0.65268
# [322]	validation_0-logloss:0.65251
# [323]	validation_0-logloss:0.65256
# [324]	validation_0-logloss:0.65232
# [325]	validation_0-logloss:0.65257
# [326]	validation_0-logloss:0.65230
# [327]	validation_0-logloss:0.65238
# [328]	validation_0-logloss:0.65200
# [329]	validation_0-logloss:0.65201
# [330]	validation_0-logloss:0.65196
# [331]	validation_0-logloss:0.65187
# [332]	validation_0-logloss:0.65183
# [333]	validation_0-logloss:0.65175
# [334]	validation_0-logloss:0.65176
# [335]	validation_0-logloss:0.65170
# [336]	validation_0-logloss:0.65189
# [337]	validation_0-logloss:0.65191
# [338]	validation_0-logloss:0.65203
# [339]	validation_0-logloss:0.65144
# [340]	validation_0-logloss:0.65140
# [341]	validation_0-logloss:0.65145
# [342]	validation_0-logloss:0.65150
# [343]	validation_0-logloss:0.65158
# [344]	validation_0-logloss:0.65153
# [345]	validation_0-logloss:0.65191
# [346]	validation_0-logloss:0.65217
# [347]	validation_0-logloss:0.65228
# [348]	validation_0-logloss:0.65243
# [349]	validation_0-logloss:0.65249
# [350]	validation_0-logloss:0.65255
# [351]	validation_0-logloss:0.65249
# [352]	validation_0-logloss:0.65289
# [353]	validation_0-logloss:0.65271
# [354]	validation_0-logloss:0.65248
# [355]	validation_0-logloss:0.65249
# [356]	validation_0-logloss:0.65237
# [357]	validation_0-logloss:0.65248
# [358]	validation_0-logloss:0.65246
# [359]	validation_0-logloss:0.65249
# [360]	validation_0-logloss:0.65250
# [361]	validation_0-logloss:0.65246
# [362]	validation_0-logloss:0.65243
# [363]	validation_0-logloss:0.65248
# [364]	validation_0-logloss:0.65248
# [365]	validation_0-logloss:0.65259
# [366]	validation_0-logloss:0.65261
# [367]	validation_0-logloss:0.65247
# [368]	validation_0-logloss:0.65286
# [369]	validation_0-logloss:0.65279
# [370]	validation_0-logloss:0.65256
# [371]	validation_0-logloss:0.65253
# [372]	validation_0-logloss:0.65229
# [373]	validation_0-logloss:0.65236
# [374]	validation_0-logloss:0.65244
# [375]	validation_0-logloss:0.65238
# [376]	validation_0-logloss:0.65251
# [377]	validation_0-logloss:0.65253
# [378]	validation_0-logloss:0.65252
# [379]	validation_0-logloss:0.65258
# [380]	validation_0-logloss:0.65267
# [381]	validation_0-logloss:0.65249
# [382]	validation_0-logloss:0.65243
# [383]	validation_0-logloss:0.65234
# [384]	validation_0-logloss:0.65240
# [385]	validation_0-logloss:0.65246
# [386]	validation_0-logloss:0.65245
# [387]	validation_0-logloss:0.65257
# [388]	validation_0-logloss:0.65273
# [389]	validation_0-logloss:0.65266
# [390]	validation_0-logloss:0.65255
# [391]	validation_0-logloss:0.65263
# [392]	validation_0-logloss:0.65285
# [393]	validation_0-logloss:0.65278
# [394]	validation_0-logloss:0.65274
# [395]	validation_0-logloss:0.65278
# [396]	validation_0-logloss:0.65254
# [397]	validation_0-logloss:0.65251
# [398]	validation_0-logloss:0.65199
# [399]	validation_0-logloss:0.65183
# [400]	validation_0-logloss:0.65150
# [401]	validation_0-logloss:0.65151
# [402]	validation_0-logloss:0.65121
# [403]	validation_0-logloss:0.65130
# [404]	validation_0-logloss:0.65137
# [405]	validation_0-logloss:0.65142
# [406]	validation_0-logloss:0.65149
# [407]	validation_0-logloss:0.65148
# [408]	validation_0-logloss:0.65154
# [409]	validation_0-logloss:0.65133
# [410]	validation_0-logloss:0.65143
# [411]	validation_0-logloss:0.65144
# [412]	validation_0-logloss:0.65141
# [413]	validation_0-logloss:0.65128
# [414]	validation_0-logloss:0.65154
# [415]	validation_0-logloss:0.65143
# [416]	validation_0-logloss:0.65169
# [417]	validation_0-logloss:0.65167
# [418]	validation_0-logloss:0.65178
# [419]	validation_0-logloss:0.65199
# [420]	validation_0-logloss:0.65178
# [421]	validation_0-logloss:0.65187
# [422]	validation_0-logloss:0.65177
# [423]	validation_0-logloss:0.65180
# [424]	validation_0-logloss:0.65194
# [425]	validation_0-logloss:0.65183
# [426]	validation_0-logloss:0.65195
# [427]	validation_0-logloss:0.65182
# [428]	validation_0-logloss:0.65197
# [429]	validation_0-logloss:0.65192
# [430]	validation_0-logloss:0.65150
# [431]	validation_0-logloss:0.65122
# [432]	validation_0-logloss:0.65139
# [433]	validation_0-logloss:0.65142
# [434]	validation_0-logloss:0.65135
# [435]	validation_0-logloss:0.65134
# [436]	validation_0-logloss:0.65136
# [437]	validation_0-logloss:0.65136
# [438]	validation_0-logloss:0.65121
# [439]	validation_0-logloss:0.65130
# [440]	validation_0-logloss:0.65134
# [441]	validation_0-logloss:0.65140
# [442]	validation_0-logloss:0.65145
# [443]	validation_0-logloss:0.65150
# [444]	validation_0-logloss:0.65161
# [445]	validation_0-logloss:0.65167
# [446]	validation_0-logloss:0.65164
# [447]	validation_0-logloss:0.65158
# [448]	validation_0-logloss:0.65154
# [449]	validation_0-logloss:0.65158
# [450]	validation_0-logloss:0.65162
# [451]	validation_0-logloss:0.65166
# [452]	validation_0-logloss:0.65161
# [453]	validation_0-logloss:0.65168
# [454]	validation_0-logloss:0.65135
# [455]	validation_0-logloss:0.65145
# [456]	validation_0-logloss:0.65144
# [457]	validation_0-logloss:0.65138
# [458]	validation_0-logloss:0.65132
# [459]	validation_0-logloss:0.65121
# [460]	validation_0-logloss:0.65115
# [461]	validation_0-logloss:0.65104
# [462]	validation_0-logloss:0.65028
# [463]	validation_0-logloss:0.65021
# [464]	validation_0-logloss:0.65025
# [465]	validation_0-logloss:0.65027
# [466]	validation_0-logloss:0.65037
# [467]	validation_0-logloss:0.65019
# [468]	validation_0-logloss:0.65009
# [469]	validation_0-logloss:0.65013
# [470]	validation_0-logloss:0.65007
# [471]	validation_0-logloss:0.65001
# [472]	validation_0-logloss:0.65000
# [473]	validation_0-logloss:0.64989
# [474]	validation_0-logloss:0.64944
# [475]	validation_0-logloss:0.64900
# [476]	validation_0-logloss:0.64910
# [477]	validation_0-logloss:0.64908
# [478]	validation_0-logloss:0.64906
# [479]	validation_0-logloss:0.64905
# [480]	validation_0-logloss:0.64908
# [481]	validation_0-logloss:0.64912
# [482]	validation_0-logloss:0.64931
# [483]	validation_0-logloss:0.64919
# [484]	validation_0-logloss:0.64912
# [485]	validation_0-logloss:0.64912
# [486]	validation_0-logloss:0.64906
# [487]	validation_0-logloss:0.64905
# [488]	validation_0-logloss:0.64924
# [489]	validation_0-logloss:0.64919
# [490]	validation_0-logloss:0.64930
# [491]	validation_0-logloss:0.64930
# [492]	validation_0-logloss:0.64922
# [493]	validation_0-logloss:0.64898
# [494]	validation_0-logloss:0.64846
# [495]	validation_0-logloss:0.64829
# [496]	validation_0-logloss:0.64832
# [497]	validation_0-logloss:0.64831
# [498]	validation_0-logloss:0.64828
# [499]	validation_0-logloss:0.64837
# [500]	validation_0-logloss:0.64852
# [501]	validation_0-logloss:0.64848
# [502]	validation_0-logloss:0.64852
# [503]	validation_0-logloss:0.64838
# [504]	validation_0-logloss:0.64832
# [505]	validation_0-logloss:0.64825
# [506]	validation_0-logloss:0.64834
# [507]	validation_0-logloss:0.64830
# [508]	validation_0-logloss:0.64828
# [509]	validation_0-logloss:0.64831
# [510]	validation_0-logloss:0.64826
# [511]	validation_0-logloss:0.64821
# [512]	validation_0-logloss:0.64818
# [513]	validation_0-logloss:0.64817
# [514]	validation_0-logloss:0.64836
# [515]	validation_0-logloss:0.64833
# [516]	validation_0-logloss:0.64834
# [517]	validation_0-logloss:0.64835
# [518]	validation_0-logloss:0.64835
# [519]	validation_0-logloss:0.64816
# [520]	validation_0-logloss:0.64824
# [521]	validation_0-logloss:0.64794
# [522]	validation_0-logloss:0.64788
# [523]	validation_0-logloss:0.64793
# [524]	validation_0-logloss:0.64807
# [525]	validation_0-logloss:0.64798
# [526]	validation_0-logloss:0.64801
# [527]	validation_0-logloss:0.64802
# [528]	validation_0-logloss:0.64813
# [529]	validation_0-logloss:0.64817
# [530]	validation_0-logloss:0.64818
# [531]	validation_0-logloss:0.64825
# [532]	validation_0-logloss:0.64823
# [533]	validation_0-logloss:0.64795
# [534]	validation_0-logloss:0.64798
# [535]	validation_0-logloss:0.64806
# [536]	validation_0-logloss:0.64788
# [537]	validation_0-logloss:0.64757
# [538]	validation_0-logloss:0.64753
# [539]	validation_0-logloss:0.64735
# [540]	validation_0-logloss:0.64735
# [541]	validation_0-logloss:0.64740
# [542]	validation_0-logloss:0.64729
# [543]	validation_0-logloss:0.64727
# [544]	validation_0-logloss:0.64724
# [545]	validation_0-logloss:0.64724
# [546]	validation_0-logloss:0.64686
# [547]	validation_0-logloss:0.64672
# [548]	validation_0-logloss:0.64671
# [549]	validation_0-logloss:0.64659
# [550]	validation_0-logloss:0.64659
# [551]	validation_0-logloss:0.64669
# [552]	validation_0-logloss:0.64661
# [553]	validation_0-logloss:0.64653
# [554]	validation_0-logloss:0.64651
# [555]	validation_0-logloss:0.64656
# [556]	validation_0-logloss:0.64669
# [557]	validation_0-logloss:0.64671
# [558]	validation_0-logloss:0.64713
# [559]	validation_0-logloss:0.64707
# [560]	validation_0-logloss:0.64698
# [561]	validation_0-logloss:0.64728
# [562]	validation_0-logloss:0.64742
# [563]	validation_0-logloss:0.64745
# [564]	validation_0-logloss:0.64753
# [565]	validation_0-logloss:0.64775
# [566]	validation_0-logloss:0.64758
# [567]	validation_0-logloss:0.64760
# [568]	validation_0-logloss:0.64748
# [569]	validation_0-logloss:0.64763
# [570]	validation_0-logloss:0.64745
# [571]	validation_0-logloss:0.64751
# [572]	validation_0-logloss:0.64741
# [573]	validation_0-logloss:0.64751
# [574]	validation_0-logloss:0.64743
# [575]	validation_0-logloss:0.64744
# [576]	validation_0-logloss:0.64728
# [577]	validation_0-logloss:0.64761
# [578]	validation_0-logloss:0.64756
# [579]	validation_0-logloss:0.64760
# [580]	validation_0-logloss:0.64730
# [581]	validation_0-logloss:0.64736
# [582]	validation_0-logloss:0.64761
# [583]	validation_0-logloss:0.64733
# [584]	validation_0-logloss:0.64759
# [585]	validation_0-logloss:0.64770
# [586]	validation_0-logloss:0.64762
# [587]	validation_0-logloss:0.64698
# [588]	validation_0-logloss:0.64701
# [589]	validation_0-logloss:0.64705
# [590]	validation_0-logloss:0.64704
# [591]	validation_0-logloss:0.64711
# [592]	validation_0-logloss:0.64707
# [593]	validation_0-logloss:0.64717
# [594]	validation_0-logloss:0.64722
# [595]	validation_0-logloss:0.64732
# [596]	validation_0-logloss:0.64730
# [597]	validation_0-logloss:0.64722
# [598]	validation_0-logloss:0.64711
# [599]	validation_0-logloss:0.64719
# [600]	validation_0-logloss:0.64715
# [601]	validation_0-logloss:0.64722
# [602]	validation_0-logloss:0.64733
# [603]	validation_0-logloss:0.64765
# [604]	validation_0-logloss:0.64735
# [605]	validation_0-logloss:0.64734
# [606]	validation_0-logloss:0.64733
# [607]	validation_0-logloss:0.64710
# [608]	validation_0-logloss:0.64716
# [609]	validation_0-logloss:0.64707
# [610]	validation_0-logloss:0.64694
# [611]	validation_0-logloss:0.64705
# [612]	validation_0-logloss:0.64707
# [613]	validation_0-logloss:0.64693
# [614]	validation_0-logloss:0.64684
# [615]	validation_0-logloss:0.64683
# [616]	validation_0-logloss:0.64673
# [617]	validation_0-logloss:0.64665
# [618]	validation_0-logloss:0.64659
# [619]	validation_0-logloss:0.64660
# [620]	validation_0-logloss:0.64662
# [621]	validation_0-logloss:0.64660
# [622]	validation_0-logloss:0.64654
# [623]	validation_0-logloss:0.64672
# [624]	validation_0-logloss:0.64684
# [625]	validation_0-logloss:0.64681
# [626]	validation_0-logloss:0.64639
# [627]	validation_0-logloss:0.64646
# [628]	validation_0-logloss:0.64629
# [629]	validation_0-logloss:0.64628
# [630]	validation_0-logloss:0.64624
# [631]	validation_0-logloss:0.64578
# [632]	validation_0-logloss:0.64582
# [633]	validation_0-logloss:0.64604
# [634]	validation_0-logloss:0.64616
# [635]	validation_0-logloss:0.64593
# [636]	validation_0-logloss:0.64598
# [637]	validation_0-logloss:0.64597
# [638]	validation_0-logloss:0.64613
# [639]	validation_0-logloss:0.64617
# [640]	validation_0-logloss:0.64623
# [641]	validation_0-logloss:0.64610
# [642]	validation_0-logloss:0.64602
# [643]	validation_0-logloss:0.64583
# [644]	validation_0-logloss:0.64587
# [645]	validation_0-logloss:0.64571
# [646]	validation_0-logloss:0.64570
# [647]	validation_0-logloss:0.64566
# [648]	validation_0-logloss:0.64556
# [649]	validation_0-logloss:0.64550
# [650]	validation_0-logloss:0.64537
# [651]	validation_0-logloss:0.64531
# [652]	validation_0-logloss:0.64519
# [653]	validation_0-logloss:0.64511
# [654]	validation_0-logloss:0.64498
# [655]	validation_0-logloss:0.64485
# [656]	validation_0-logloss:0.64475
# [657]	validation_0-logloss:0.64476
# [658]	validation_0-logloss:0.64483
# [659]	validation_0-logloss:0.64471
# [660]	validation_0-logloss:0.64475
# [661]	validation_0-logloss:0.64486
# [662]	validation_0-logloss:0.64482
# [663]	validation_0-logloss:0.64463
# [664]	validation_0-logloss:0.64469
# [665]	validation_0-logloss:0.64482
# [666]	validation_0-logloss:0.64494
# [667]	validation_0-logloss:0.64490
# [668]	validation_0-logloss:0.64489
# [669]	validation_0-logloss:0.64479
# [670]	validation_0-logloss:0.64489
# [671]	validation_0-logloss:0.64491
# [672]	validation_0-logloss:0.64510
# [673]	validation_0-logloss:0.64494
# [674]	validation_0-logloss:0.64493
# [675]	validation_0-logloss:0.64473
# [676]	validation_0-logloss:0.64463
# [677]	validation_0-logloss:0.64477
# [678]	validation_0-logloss:0.64492
# [679]	validation_0-logloss:0.64485
# [680]	validation_0-logloss:0.64466
# [681]	validation_0-logloss:0.64471
# [682]	validation_0-logloss:0.64486
# [683]	validation_0-logloss:0.64488
# [684]	validation_0-logloss:0.64469
# [685]	validation_0-logloss:0.64447
# [686]	validation_0-logloss:0.64445
# [687]	validation_0-logloss:0.64420
# [688]	validation_0-logloss:0.64423
# [689]	validation_0-logloss:0.64418
# [690]	validation_0-logloss:0.64412
# [691]	validation_0-logloss:0.64406
# [692]	validation_0-logloss:0.64432
# [693]	validation_0-logloss:0.64448
# [694]	validation_0-logloss:0.64416
# [695]	validation_0-logloss:0.64419
# [696]	validation_0-logloss:0.64443
# [697]	validation_0-logloss:0.64444
# [698]	validation_0-logloss:0.64451
# [699]	validation_0-logloss:0.64443
# [700]	validation_0-logloss:0.64457
# [701]	validation_0-logloss:0.64468
# [702]	validation_0-logloss:0.64482
# [703]	validation_0-logloss:0.64471
# [704]	validation_0-logloss:0.64472
# [705]	validation_0-logloss:0.64463
# [706]	validation_0-logloss:0.64463
# [707]	validation_0-logloss:0.64455
# [708]	validation_0-logloss:0.64476
# [709]	validation_0-logloss:0.64460
# [710]	validation_0-logloss:0.64449
# [711]	validation_0-logloss:0.64451
# [712]	validation_0-logloss:0.64409
# [713]	validation_0-logloss:0.64405
# [714]	validation_0-logloss:0.64419
# [715]	validation_0-logloss:0.64419
# [716]	validation_0-logloss:0.64428
# [717]	validation_0-logloss:0.64425
# [718]	validation_0-logloss:0.64417
# [719]	validation_0-logloss:0.64432
# [720]	validation_0-logloss:0.64440
# [721]	validation_0-logloss:0.64432
# [722]	validation_0-logloss:0.64430
# [723]	validation_0-logloss:0.64442
# [724]	validation_0-logloss:0.64429
# [725]	validation_0-logloss:0.64433
# [726]	validation_0-logloss:0.64428
# [727]	validation_0-logloss:0.64444
# [728]	validation_0-logloss:0.64466
# [729]	validation_0-logloss:0.64456
# [730]	validation_0-logloss:0.64455
# [731]	validation_0-logloss:0.64438
# [732]	validation_0-logloss:0.64432
# [733]	validation_0-logloss:0.64435
# [734]	validation_0-logloss:0.64467
# [735]	validation_0-logloss:0.64454
# [736]	validation_0-logloss:0.64438
# [737]	validation_0-logloss:0.64428
# [738]	validation_0-logloss:0.64431
# [739]	validation_0-logloss:0.64430
# [740]	validation_0-logloss:0.64428
# [741]	validation_0-logloss:0.64427
# [742]	validation_0-logloss:0.64441
# [743]	validation_0-logloss:0.64431
# [744]	validation_0-logloss:0.64425
# [745]	validation_0-logloss:0.64424
# [746]	validation_0-logloss:0.64429
# [747]	validation_0-logloss:0.64427
# [748]	validation_0-logloss:0.64422
# [749]	validation_0-logloss:0.64397
# [750]	validation_0-logloss:0.64383
# [751]	validation_0-logloss:0.64387
# [752]	validation_0-logloss:0.64387
# [753]	validation_0-logloss:0.64385
# [754]	validation_0-logloss:0.64382
# [755]	validation_0-logloss:0.64377
# [756]	validation_0-logloss:0.64384
# [757]	validation_0-logloss:0.64377
# [758]	validation_0-logloss:0.64378
# [759]	validation_0-logloss:0.64381
# [760]	validation_0-logloss:0.64354
# [761]	validation_0-logloss:0.64356
# [762]	validation_0-logloss:0.64354
# [763]	validation_0-logloss:0.64349
# [764]	validation_0-logloss:0.64351
# [765]	validation_0-logloss:0.64349
# [766]	validation_0-logloss:0.64344
# [767]	validation_0-logloss:0.64349
# [768]	validation_0-logloss:0.64339
# [769]	validation_0-logloss:0.64331
# [770]	validation_0-logloss:0.64339
# [771]	validation_0-logloss:0.64332
# [772]	validation_0-logloss:0.64324
# [773]	validation_0-logloss:0.64336
# [774]	validation_0-logloss:0.64315
# [775]	validation_0-logloss:0.64315
# [776]	validation_0-logloss:0.64313
# [777]	validation_0-logloss:0.64305
# [778]	validation_0-logloss:0.64306
# [779]	validation_0-logloss:0.64316
# [780]	validation_0-logloss:0.64314
# [781]	validation_0-logloss:0.64321
# [782]	validation_0-logloss:0.64322
# [783]	validation_0-logloss:0.64324
# [784]	validation_0-logloss:0.64320
# [785]	validation_0-logloss:0.64319
# [786]	validation_0-logloss:0.64302
# [787]	validation_0-logloss:0.64303
# [788]	validation_0-logloss:0.64301
# [789]	validation_0-logloss:0.64291
# [790]	validation_0-logloss:0.64257
# [791]	validation_0-logloss:0.64252
# [792]	validation_0-logloss:0.64285
# [793]	validation_0-logloss:0.64245
# [794]	validation_0-logloss:0.64241
# [795]	validation_0-logloss:0.64234
# [796]	validation_0-logloss:0.64229
# [797]	validation_0-logloss:0.64203
# [798]	validation_0-logloss:0.64194
# [799]	validation_0-logloss:0.64204
# [0]	validation_0-logloss:0.69228
# [1]	validation_0-logloss:0.69140
# [2]	validation_0-logloss:0.69053
# [3]	validation_0-logloss:0.68975
# [4]	validation_0-logloss:0.68890
# [5]	validation_0-logloss:0.68811
# [6]	validation_0-logloss:0.68731
# [7]	validation_0-logloss:0.68666
# [8]	validation_0-logloss:0.68599
# [9]	validation_0-logloss:0.68537
# [10]	validation_0-logloss:0.68464
# [11]	validation_0-logloss:0.68400
# [12]	validation_0-logloss:0.68348
# [13]	validation_0-logloss:0.68282
# [14]	validation_0-logloss:0.68209
# [15]	validation_0-logloss:0.68154
# [16]	validation_0-logloss:0.68092
# [17]	validation_0-logloss:0.68037
# [18]	validation_0-logloss:0.67991
# [19]	validation_0-logloss:0.67932
# [20]	validation_0-logloss:0.67877
# [21]	validation_0-logloss:0.67832
# [22]	validation_0-logloss:0.67783
# [23]	validation_0-logloss:0.67742
# [24]	validation_0-logloss:0.67694
# [25]	validation_0-logloss:0.67648
# [26]	validation_0-logloss:0.67613
# [27]	validation_0-logloss:0.67574
# [28]	validation_0-logloss:0.67533
# [29]	validation_0-logloss:0.67499
# [30]	validation_0-logloss:0.67463
# [31]	validation_0-logloss:0.67430
# [32]	validation_0-logloss:0.67387
# [33]	validation_0-logloss:0.67362
# [34]	validation_0-logloss:0.67339
# [35]	validation_0-logloss:0.67309
# [36]	validation_0-logloss:0.67284
# [37]	validation_0-logloss:0.67260
# [38]	validation_0-logloss:0.67212
# [39]	validation_0-logloss:0.67185
# [40]	validation_0-logloss:0.67154
# [41]	validation_0-logloss:0.67124
# [42]	validation_0-logloss:0.67096
# [43]	validation_0-logloss:0.67057
# [44]	validation_0-logloss:0.67038
# [45]	validation_0-logloss:0.67015
# [46]	validation_0-logloss:0.66994
# [47]	validation_0-logloss:0.66967
# [48]	validation_0-logloss:0.66934
# [49]	validation_0-logloss:0.66907
# [50]	validation_0-logloss:0.66875
# [51]	validation_0-logloss:0.66848
# [52]	validation_0-logloss:0.66818
# [53]	validation_0-logloss:0.66794
# [54]	validation_0-logloss:0.66787
# [55]	validation_0-logloss:0.66767
# [56]	validation_0-logloss:0.66759
# [57]	validation_0-logloss:0.66743
# [58]	validation_0-logloss:0.66725
# [59]	validation_0-logloss:0.66700
# [60]	validation_0-logloss:0.66689
# [61]	validation_0-logloss:0.66676
# [62]	validation_0-logloss:0.66645
# [63]	validation_0-logloss:0.66643
# [64]	validation_0-logloss:0.66626
# [65]	validation_0-logloss:0.66610
# [66]	validation_0-logloss:0.66596
# [67]	validation_0-logloss:0.66578
# [68]	validation_0-logloss:0.66564
# [69]	validation_0-logloss:0.66537
# [70]	validation_0-logloss:0.66516
# [71]	validation_0-logloss:0.66504
# [72]	validation_0-logloss:0.66486
# [73]	validation_0-logloss:0.66470
# [74]	validation_0-logloss:0.66449
# [75]	validation_0-logloss:0.66428
# [76]	validation_0-logloss:0.66399
# [77]	validation_0-logloss:0.66405
# [78]	validation_0-logloss:0.66375
# [79]	validation_0-logloss:0.66362
# [80]	validation_0-logloss:0.66350
# [81]	validation_0-logloss:0.66345
# [82]	validation_0-logloss:0.66333
# [83]	validation_0-logloss:0.66329
# [84]	validation_0-logloss:0.66315
# [85]	validation_0-logloss:0.66301
# [86]	validation_0-logloss:0.66282
# [87]	validation_0-logloss:0.66262
# [88]	validation_0-logloss:0.66247
# [89]	validation_0-logloss:0.66217
# [90]	validation_0-logloss:0.66206
# [91]	validation_0-logloss:0.66201
# [92]	validation_0-logloss:0.66205
# [93]	validation_0-logloss:0.66196
# [94]	validation_0-logloss:0.66190
# [95]	validation_0-logloss:0.66190
# [96]	validation_0-logloss:0.66173
# [97]	validation_0-logloss:0.66168
# [98]	validation_0-logloss:0.66158
# [99]	validation_0-logloss:0.66157
# [100]	validation_0-logloss:0.66119
# [101]	validation_0-logloss:0.66109
# [102]	validation_0-logloss:0.66098
# [103]	validation_0-logloss:0.66093
# [104]	validation_0-logloss:0.66082
# [105]	validation_0-logloss:0.66075
# [106]	validation_0-logloss:0.66063
# [107]	validation_0-logloss:0.66071
# [108]	validation_0-logloss:0.66063
# [109]	validation_0-logloss:0.66057
# [110]	validation_0-logloss:0.66049
# [111]	validation_0-logloss:0.66045
# [112]	validation_0-logloss:0.66044
# [113]	validation_0-logloss:0.66031
# [114]	validation_0-logloss:0.66022
# [115]	validation_0-logloss:0.66022
# [116]	validation_0-logloss:0.66008
# [117]	validation_0-logloss:0.66006
# [118]	validation_0-logloss:0.65981
# [119]	validation_0-logloss:0.65974
# [120]	validation_0-logloss:0.65963
# [121]	validation_0-logloss:0.65942
# [122]	validation_0-logloss:0.65937
# [123]	validation_0-logloss:0.65939
# [124]	validation_0-logloss:0.65937
# [125]	validation_0-logloss:0.65926
# [126]	validation_0-logloss:0.65926
# [127]	validation_0-logloss:0.65924
# [128]	validation_0-logloss:0.65918
# [129]	validation_0-logloss:0.65935
# [130]	validation_0-logloss:0.65909
# [131]	validation_0-logloss:0.65906
# [132]	validation_0-logloss:0.65907
# [133]	validation_0-logloss:0.65913
# [134]	validation_0-logloss:0.65924
# [135]	validation_0-logloss:0.65910
# [136]	validation_0-logloss:0.65896
# [137]	validation_0-logloss:0.65883
# [138]	validation_0-logloss:0.65875
# [139]	validation_0-logloss:0.65870
# [140]	validation_0-logloss:0.65846
# [141]	validation_0-logloss:0.65838
# [142]	validation_0-logloss:0.65826
# [143]	validation_0-logloss:0.65825
# [144]	validation_0-logloss:0.65816
# [145]	validation_0-logloss:0.65811
# [146]	validation_0-logloss:0.65796
# [147]	validation_0-logloss:0.65799
# [148]	validation_0-logloss:0.65793
# [149]	validation_0-logloss:0.65781
# [150]	validation_0-logloss:0.65779
# [151]	validation_0-logloss:0.65773
# [152]	validation_0-logloss:0.65776
# [153]	validation_0-logloss:0.65778
# [154]	validation_0-logloss:0.65759
# [155]	validation_0-logloss:0.65745
# [156]	validation_0-logloss:0.65748
# [157]	validation_0-logloss:0.65738
# [158]	validation_0-logloss:0.65761
# [159]	validation_0-logloss:0.65758
# [160]	validation_0-logloss:0.65759
# [161]	validation_0-logloss:0.65769
# [162]	validation_0-logloss:0.65765
# [163]	validation_0-logloss:0.65785
# [164]	validation_0-logloss:0.65776
# [165]	validation_0-logloss:0.65783
# [166]	validation_0-logloss:0.65782
# [167]	validation_0-logloss:0.65784
# [168]	validation_0-logloss:0.65787
# [169]	validation_0-logloss:0.65782
# [170]	validation_0-logloss:0.65768
# [171]	validation_0-logloss:0.65773
# [172]	validation_0-logloss:0.65770
# [173]	validation_0-logloss:0.65753
# [174]	validation_0-logloss:0.65743
# [175]	validation_0-logloss:0.65727
# [176]	validation_0-logloss:0.65723
# [177]	validation_0-logloss:0.65730
# [178]	validation_0-logloss:0.65726
# [179]	validation_0-logloss:0.65716
# [180]	validation_0-logloss:0.65715
# [181]	validation_0-logloss:0.65715
# [182]	validation_0-logloss:0.65721
# [183]	validation_0-logloss:0.65725
# [184]	validation_0-logloss:0.65731
# [185]	validation_0-logloss:0.65748
# [186]	validation_0-logloss:0.65746
# [187]	validation_0-logloss:0.65747
# [188]	validation_0-logloss:0.65744
# [189]	validation_0-logloss:0.65732
# [190]	validation_0-logloss:0.65722
# [191]	validation_0-logloss:0.65720
# [192]	validation_0-logloss:0.65739
# [193]	validation_0-logloss:0.65753
# [194]	validation_0-logloss:0.65740
# [195]	validation_0-logloss:0.65740
# [196]	validation_0-logloss:0.65712
# [197]	validation_0-logloss:0.65711
# [198]	validation_0-logloss:0.65705
# [199]	validation_0-logloss:0.65692
# [200]	validation_0-logloss:0.65671
# [201]	validation_0-logloss:0.65667
# [202]	validation_0-logloss:0.65672
# [203]	validation_0-logloss:0.65697
# [204]	validation_0-logloss:0.65693
# [205]	validation_0-logloss:0.65701
# [206]	validation_0-logloss:0.65707
# [207]	validation_0-logloss:0.65696
# [208]	validation_0-logloss:0.65679
# [209]	validation_0-logloss:0.65684
# [210]	validation_0-logloss:0.65702
# [211]	validation_0-logloss:0.65691
# [212]	validation_0-logloss:0.65681
# [213]	validation_0-logloss:0.65675
# [214]	validation_0-logloss:0.65671
# [215]	validation_0-logloss:0.65656
# [216]	validation_0-logloss:0.65624
# [217]	validation_0-logloss:0.65616
# [218]	validation_0-logloss:0.65575
# [219]	validation_0-logloss:0.65558
# [220]	validation_0-logloss:0.65538
# [221]	validation_0-logloss:0.65545
# [222]	validation_0-logloss:0.65541
# [223]	validation_0-logloss:0.65496
# [224]	validation_0-logloss:0.65506
# [225]	validation_0-logloss:0.65501
# [226]	validation_0-logloss:0.65513
# [227]	validation_0-logloss:0.65512
# [228]	validation_0-logloss:0.65485
# [229]	validation_0-logloss:0.65481
# [230]	validation_0-logloss:0.65482
# [231]	validation_0-logloss:0.65477
# [232]	validation_0-logloss:0.65490
# [233]	validation_0-logloss:0.65485
# [234]	validation_0-logloss:0.65484
# [235]	validation_0-logloss:0.65484
# [236]	validation_0-logloss:0.65476
# [237]	validation_0-logloss:0.65462
# [238]	validation_0-logloss:0.65456
# [239]	validation_0-logloss:0.65464
# [240]	validation_0-logloss:0.65476
# [241]	validation_0-logloss:0.65477
# [242]	validation_0-logloss:0.65471
# [243]	validation_0-logloss:0.65467
# [244]	validation_0-logloss:0.65487
# [245]	validation_0-logloss:0.65489
# [246]	validation_0-logloss:0.65494
# [247]	validation_0-logloss:0.65501
# [248]	validation_0-logloss:0.65507
# [249]	validation_0-logloss:0.65527
# [250]	validation_0-logloss:0.65505
# [251]	validation_0-logloss:0.65507
# [252]	validation_0-logloss:0.65500
# [253]	validation_0-logloss:0.65477
# [254]	validation_0-logloss:0.65470
# [255]	validation_0-logloss:0.65482
# [256]	validation_0-logloss:0.65457
# [257]	validation_0-logloss:0.65483
# [258]	validation_0-logloss:0.65469
# [259]	validation_0-logloss:0.65473
# [260]	validation_0-logloss:0.65463
# [261]	validation_0-logloss:0.65459
# [262]	validation_0-logloss:0.65459
# [263]	validation_0-logloss:0.65441
# [264]	validation_0-logloss:0.65437
# [265]	validation_0-logloss:0.65425
# [266]	validation_0-logloss:0.65412
# [267]	validation_0-logloss:0.65400
# [268]	validation_0-logloss:0.65406
# [269]	validation_0-logloss:0.65418
# [270]	validation_0-logloss:0.65418
# [271]	validation_0-logloss:0.65410
# [272]	validation_0-logloss:0.65420
# [273]	validation_0-logloss:0.65407
# [274]	validation_0-logloss:0.65412
# [275]	validation_0-logloss:0.65415
# [276]	validation_0-logloss:0.65393
# [277]	validation_0-logloss:0.65391
# [278]	validation_0-logloss:0.65398
# [279]	validation_0-logloss:0.65395
# [280]	validation_0-logloss:0.65387
# [281]	validation_0-logloss:0.65392
# [282]	validation_0-logloss:0.65394
# [283]	validation_0-logloss:0.65338
# [284]	validation_0-logloss:0.65337
# [285]	validation_0-logloss:0.65337
# [286]	validation_0-logloss:0.65342
# [287]	validation_0-logloss:0.65355
# [288]	validation_0-logloss:0.65350
# [289]	validation_0-logloss:0.65357
# [290]	validation_0-logloss:0.65342
# [291]	validation_0-logloss:0.65350
# [292]	validation_0-logloss:0.65345
# [293]	validation_0-logloss:0.65318
# [294]	validation_0-logloss:0.65312
# [295]	validation_0-logloss:0.65321
# [296]	validation_0-logloss:0.65315
# [297]	validation_0-logloss:0.65327
# [298]	validation_0-logloss:0.65338
# [299]	validation_0-logloss:0.65332
# [300]	validation_0-logloss:0.65334
# [301]	validation_0-logloss:0.65325
# [302]	validation_0-logloss:0.65318
# [303]	validation_0-logloss:0.65314
# [304]	validation_0-logloss:0.65298
# [305]	validation_0-logloss:0.65315
# [306]	validation_0-logloss:0.65322
# [307]	validation_0-logloss:0.65319
# [308]	validation_0-logloss:0.65339
# [309]	validation_0-logloss:0.65343
# [310]	validation_0-logloss:0.65362
# [311]	validation_0-logloss:0.65373
# [312]	validation_0-logloss:0.65369
# [313]	validation_0-logloss:0.65369
# [314]	validation_0-logloss:0.65365
# [315]	validation_0-logloss:0.65320
# [316]	validation_0-logloss:0.65251
# [317]	validation_0-logloss:0.65233
# [318]	validation_0-logloss:0.65201
# [319]	validation_0-logloss:0.65204
# [320]	validation_0-logloss:0.65204
# [321]	validation_0-logloss:0.65168
# [322]	validation_0-logloss:0.65163
# [323]	validation_0-logloss:0.65160
# [324]	validation_0-logloss:0.65162
# [325]	validation_0-logloss:0.65152
# [326]	validation_0-logloss:0.65145
# [327]	validation_0-logloss:0.65156
# [328]	validation_0-logloss:0.65153
# [329]	validation_0-logloss:0.65134
# [330]	validation_0-logloss:0.65135
# [331]	validation_0-logloss:0.65129
# [332]	validation_0-logloss:0.65128
# [333]	validation_0-logloss:0.65126
# [334]	validation_0-logloss:0.65138
# [335]	validation_0-logloss:0.65158
# [336]	validation_0-logloss:0.65135
# [337]	validation_0-logloss:0.65127
# [338]	validation_0-logloss:0.65133
# [339]	validation_0-logloss:0.65132
# [340]	validation_0-logloss:0.65129
# [341]	validation_0-logloss:0.65129
# [342]	validation_0-logloss:0.65136
# [343]	validation_0-logloss:0.65124
# [344]	validation_0-logloss:0.65096
# [345]	validation_0-logloss:0.65085
# [346]	validation_0-logloss:0.65069
# [347]	validation_0-logloss:0.65075
# [348]	validation_0-logloss:0.65057
# [349]	validation_0-logloss:0.65076
# [350]	validation_0-logloss:0.65051
# [351]	validation_0-logloss:0.65039
# [352]	validation_0-logloss:0.65025
# [353]	validation_0-logloss:0.65011
# [354]	validation_0-logloss:0.65020
# [355]	validation_0-logloss:0.65006
# [356]	validation_0-logloss:0.65020
# [357]	validation_0-logloss:0.64991
# [358]	validation_0-logloss:0.64980
# [359]	validation_0-logloss:0.64978
# [360]	validation_0-logloss:0.64978
# [361]	validation_0-logloss:0.64960
# [362]	validation_0-logloss:0.64961
# [363]	validation_0-logloss:0.64916
# [364]	validation_0-logloss:0.64941
# [365]	validation_0-logloss:0.64929
# [366]	validation_0-logloss:0.64924
# [367]	validation_0-logloss:0.64922
# [368]	validation_0-logloss:0.64910
# [369]	validation_0-logloss:0.64922
# [370]	validation_0-logloss:0.64925
# [371]	validation_0-logloss:0.64918
# [372]	validation_0-logloss:0.64909
# [373]	validation_0-logloss:0.64920
# [374]	validation_0-logloss:0.64915
# [375]	validation_0-logloss:0.64941
# [376]	validation_0-logloss:0.64910
# [377]	validation_0-logloss:0.64904
# [378]	validation_0-logloss:0.64905
# [379]	validation_0-logloss:0.64915
# [380]	validation_0-logloss:0.64919
# [381]	validation_0-logloss:0.64890
# [382]	validation_0-logloss:0.64895
# [383]	validation_0-logloss:0.64912
# [384]	validation_0-logloss:0.64920
# [385]	validation_0-logloss:0.64912
# [386]	validation_0-logloss:0.64903
# [387]	validation_0-logloss:0.64913
# [388]	validation_0-logloss:0.64904
# [389]	validation_0-logloss:0.64888
# [390]	validation_0-logloss:0.64901
# [391]	validation_0-logloss:0.64896
# [392]	validation_0-logloss:0.64865
# [393]	validation_0-logloss:0.64871
# [394]	validation_0-logloss:0.64851
# [395]	validation_0-logloss:0.64865
# [396]	validation_0-logloss:0.64881
# [397]	validation_0-logloss:0.64879
# [398]	validation_0-logloss:0.64881
# [399]	validation_0-logloss:0.64736
# [400]	validation_0-logloss:0.64761
# [401]	validation_0-logloss:0.64756
# [402]	validation_0-logloss:0.64746
# [403]	validation_0-logloss:0.64739
# [404]	validation_0-logloss:0.64748
# [405]	validation_0-logloss:0.64737
# [406]	validation_0-logloss:0.64738
# [407]	validation_0-logloss:0.64721
# [408]	validation_0-logloss:0.64712
# [409]	validation_0-logloss:0.64701
# [410]	validation_0-logloss:0.64710
# [411]	validation_0-logloss:0.64717
# [412]	validation_0-logloss:0.64736
# [413]	validation_0-logloss:0.64734
# [414]	validation_0-logloss:0.64729
# [415]	validation_0-logloss:0.64727
# [416]	validation_0-logloss:0.64769
# [417]	validation_0-logloss:0.64767
# [418]	validation_0-logloss:0.64750
# [419]	validation_0-logloss:0.64753
# [420]	validation_0-logloss:0.64758
# [421]	validation_0-logloss:0.64752
# [422]	validation_0-logloss:0.64730
# [423]	validation_0-logloss:0.64723
# [424]	validation_0-logloss:0.64706
# [425]	validation_0-logloss:0.64695
# [426]	validation_0-logloss:0.64712
# [427]	validation_0-logloss:0.64703
# [428]	validation_0-logloss:0.64699
# [429]	validation_0-logloss:0.64710
# [430]	validation_0-logloss:0.64674
# [431]	validation_0-logloss:0.64689
# [432]	validation_0-logloss:0.64696
# [433]	validation_0-logloss:0.64693
# [434]	validation_0-logloss:0.64695
# [435]	validation_0-logloss:0.64685
# [436]	validation_0-logloss:0.64680
# [437]	validation_0-logloss:0.64680
# [438]	validation_0-logloss:0.64681
# [439]	validation_0-logloss:0.64657
# [440]	validation_0-logloss:0.64645
# [441]	validation_0-logloss:0.64607
# [442]	validation_0-logloss:0.64617
# [443]	validation_0-logloss:0.64618
# [444]	validation_0-logloss:0.64586
# [445]	validation_0-logloss:0.64590
# [446]	validation_0-logloss:0.64581
# [447]	validation_0-logloss:0.64567
# [448]	validation_0-logloss:0.64603
# [449]	validation_0-logloss:0.64603
# [450]	validation_0-logloss:0.64598
# [451]	validation_0-logloss:0.64588
# [452]	validation_0-logloss:0.64589
# [453]	validation_0-logloss:0.64610
# [454]	validation_0-logloss:0.64576
# [455]	validation_0-logloss:0.64574
# [456]	validation_0-logloss:0.64572
# [457]	validation_0-logloss:0.64588
# [458]	validation_0-logloss:0.64586
# [459]	validation_0-logloss:0.64573
# [460]	validation_0-logloss:0.64585
# [461]	validation_0-logloss:0.64592
# [462]	validation_0-logloss:0.64581
# [463]	validation_0-logloss:0.64591
# [464]	validation_0-logloss:0.64578
# [465]	validation_0-logloss:0.64596
# [466]	validation_0-logloss:0.64595
# [467]	validation_0-logloss:0.64589
# [468]	validation_0-logloss:0.64583
# [469]	validation_0-logloss:0.64545
# [470]	validation_0-logloss:0.64511
# [471]	validation_0-logloss:0.64522
# [472]	validation_0-logloss:0.64533
# [473]	validation_0-logloss:0.64534
# [474]	validation_0-logloss:0.64530
# [475]	validation_0-logloss:0.64509
# [476]	validation_0-logloss:0.64494
# [477]	validation_0-logloss:0.64508
# [478]	validation_0-logloss:0.64504
# [479]	validation_0-logloss:0.64505
# [480]	validation_0-logloss:0.64488
# [481]	validation_0-logloss:0.64485
# [482]	validation_0-logloss:0.64487
# [483]	validation_0-logloss:0.64468
# [484]	validation_0-logloss:0.64478
# [485]	validation_0-logloss:0.64473
# [486]	validation_0-logloss:0.64486
# [487]	validation_0-logloss:0.64490
# [488]	validation_0-logloss:0.64481
# [489]	validation_0-logloss:0.64479
# [490]	validation_0-logloss:0.64479
# [491]	validation_0-logloss:0.64476
# [492]	validation_0-logloss:0.64479
# [493]	validation_0-logloss:0.64463
# [494]	validation_0-logloss:0.64458
# [495]	validation_0-logloss:0.64433
# [496]	validation_0-logloss:0.64431
# [497]	validation_0-logloss:0.64391
# [498]	validation_0-logloss:0.64390
# [499]	validation_0-logloss:0.64418
# [500]	validation_0-logloss:0.64416
# [501]	validation_0-logloss:0.64427
# [502]	validation_0-logloss:0.64415
# [503]	validation_0-logloss:0.64417
# [504]	validation_0-logloss:0.64420
# [505]	validation_0-logloss:0.64407
# [506]	validation_0-logloss:0.64405
# [507]	validation_0-logloss:0.64404
# [508]	validation_0-logloss:0.64391
# [509]	validation_0-logloss:0.64401
# [510]	validation_0-logloss:0.64374
# [511]	validation_0-logloss:0.64405
# [512]	validation_0-logloss:0.64413
# [513]	validation_0-logloss:0.64433
# [514]	validation_0-logloss:0.64448
# [515]	validation_0-logloss:0.64461
# [516]	validation_0-logloss:0.64464
# [517]	validation_0-logloss:0.64471
# [518]	validation_0-logloss:0.64460
# [519]	validation_0-logloss:0.64446
# [520]	validation_0-logloss:0.64447
# [521]	validation_0-logloss:0.64460
# [522]	validation_0-logloss:0.64462
# [523]	validation_0-logloss:0.64462
# [524]	validation_0-logloss:0.64473
# [525]	validation_0-logloss:0.64476
# [526]	validation_0-logloss:0.64453
# [527]	validation_0-logloss:0.64438
# [528]	validation_0-logloss:0.64445
# [529]	validation_0-logloss:0.64440
# [530]	validation_0-logloss:0.64425
# [531]	validation_0-logloss:0.64431
# [532]	validation_0-logloss:0.64430
# [533]	validation_0-logloss:0.64430
# [534]	validation_0-logloss:0.64423
# [535]	validation_0-logloss:0.64425
# [536]	validation_0-logloss:0.64419
# [537]	validation_0-logloss:0.64447
# [538]	validation_0-logloss:0.64444
# [539]	validation_0-logloss:0.64437
# [540]	validation_0-logloss:0.64434
# [541]	validation_0-logloss:0.64438
# [542]	validation_0-logloss:0.64411
# [543]	validation_0-logloss:0.64408
# [544]	validation_0-logloss:0.64403
# [545]	validation_0-logloss:0.64399
# [546]	validation_0-logloss:0.64409
# [547]	validation_0-logloss:0.64411
# [548]	validation_0-logloss:0.64408
# [549]	validation_0-logloss:0.64392
# [550]	validation_0-logloss:0.64397
# [551]	validation_0-logloss:0.64399
# [552]	validation_0-logloss:0.64417
# [553]	validation_0-logloss:0.64416
# [554]	validation_0-logloss:0.64401
# [555]	validation_0-logloss:0.64395
# [556]	validation_0-logloss:0.64392
# [557]	validation_0-logloss:0.64405
# [558]	validation_0-logloss:0.64400
# [559]	validation_0-logloss:0.64404
# [560]	validation_0-logloss:0.64406
# [561]	validation_0-logloss:0.64383
# [562]	validation_0-logloss:0.64379
# [563]	validation_0-logloss:0.64380
# [564]	validation_0-logloss:0.64363
# [565]	validation_0-logloss:0.64342
# [566]	validation_0-logloss:0.64329
# ...
# [388]	validation_0-logloss:0.52034
# [389]	validation_0-logloss:0.52020
# [390]	validation_0-logloss:0.52014
# [391]	validation_0-logloss:0.52010
# [392]	validation_0-logloss:0.52005
# [393]	validation_0-logloss:0.52009
# [394]	validation_0-logloss:0.51994
# [395]	validation_0-logloss:0.51999
# [396]	validation_0-logloss:0.51998
# [397]	validation_0-logloss:0.51986
# [398]	validation_0-logloss:0.51995
# [399]	validation_0-logloss:0.51989
# [400]	validation_0-logloss:0.51976
# [401]	validation_0-logloss:0.51987
# [402]	validation_0-logloss:0.51984
# [403]	validation_0-logloss:0.51978
# [404]	validation_0-logloss:0.51972
# [405]	validation_0-logloss:0.51954
# [406]	validation_0-logloss:0.51965
# [407]	validation_0-logloss:0.51957
# [408]	validation_0-logloss:0.51955
# [409]	validation_0-logloss:0.51953
# [410]	validation_0-logloss:0.50897
# [411]	validation_0-logloss:0.50894
# [412]	validation_0-logloss:0.50897
# [413]	validation_0-logloss:0.50895
# [414]	validation_0-logloss:0.50893
# [415]	validation_0-logloss:0.50890
# [416]	validation_0-logloss:0.50877
# [417]	validation_0-logloss:0.50880
# [418]	validation_0-logloss:0.50883
# [419]	validation_0-logloss:0.50877
# [420]	validation_0-logloss:0.50886
# [421]	validation_0-logloss:0.50886
# [422]	validation_0-logloss:0.50870
# [423]	validation_0-logloss:0.50883
# [424]	validation_0-logloss:0.50882
# [425]	validation_0-logloss:0.50887
# [426]	validation_0-logloss:0.50912
# [427]	validation_0-logloss:0.50902
# [428]	validation_0-logloss:0.50915
# [429]	validation_0-logloss:0.50913
# [430]	validation_0-logloss:0.50915
# [431]	validation_0-logloss:0.50896
# [432]	validation_0-logloss:0.50893
# [433]	validation_0-logloss:0.50896
# [434]	validation_0-logloss:0.50898
# [435]	validation_0-logloss:0.50902
# [436]	validation_0-logloss:0.50882
# [437]	validation_0-logloss:0.50893
# [438]	validation_0-logloss:0.50896
# [439]	validation_0-logloss:0.50898
# [440]	validation_0-logloss:0.50898
# [441]	validation_0-logloss:0.50901
# [442]	validation_0-logloss:0.50909
# [443]	validation_0-logloss:0.50912
# [444]	validation_0-logloss:0.50927
# [445]	validation_0-logloss:0.50945
# [446]	validation_0-logloss:0.50947
# [447]	validation_0-logloss:0.50963
# [448]	validation_0-logloss:0.50976
# [449]	validation_0-logloss:0.50979
# [450]	validation_0-logloss:0.50966
# [451]	validation_0-logloss:0.50967
# [452]	validation_0-logloss:0.50968
# [453]	validation_0-logloss:0.50990
# [454]	validation_0-logloss:0.50990
# [455]	validation_0-logloss:0.50998
# [456]	validation_0-logloss:0.50002
# [457]	validation_0-logloss:0.49986
# [458]	validation_0-logloss:0.49990
# [459]	validation_0-logloss:0.49989
# [460]	validation_0-logloss:0.50009
# [461]	validation_0-logloss:0.50003
# [462]	validation_0-logloss:0.50005
# [463]	validation_0-logloss:0.49979
# [464]	validation_0-logloss:0.49972
# [465]	validation_0-logloss:0.49966
# [466]	validation_0-logloss:0.49967
# [467]	validation_0-logloss:0.49943
# [468]	validation_0-logloss:0.49946
# [469]	validation_0-logloss:0.49936
# [470]	validation_0-logloss:0.48975
# [471]	validation_0-logloss:0.48957
# [472]	validation_0-logloss:0.48950
# [473]	validation_0-logloss:0.48952
# [474]	validation_0-logloss:0.48948
# [475]	validation_0-logloss:0.48935
# [476]	validation_0-logloss:0.48925
# [477]	validation_0-logloss:0.48916
# [478]	validation_0-logloss:0.48915
# [479]	validation_0-logloss:0.48911
# [480]	validation_0-logloss:0.48911
# [481]	validation_0-logloss:0.48912
# [482]	validation_0-logloss:0.48907
# [483]	validation_0-logloss:0.48911
# [484]	validation_0-logloss:0.48902
# [485]	validation_0-logloss:0.48906
# [486]	validation_0-logloss:0.48906
# [487]	validation_0-logloss:0.48913
# [488]	validation_0-logloss:0.48902
# [489]	validation_0-logloss:0.48893
# [490]	validation_0-logloss:0.47986
# [491]	validation_0-logloss:0.47974
# [492]	validation_0-logloss:0.47982
# [493]	validation_0-logloss:0.47987
# [494]	validation_0-logloss:0.47987
# [495]	validation_0-logloss:0.47989
# [496]	validation_0-logloss:0.47982
# [497]	validation_0-logloss:0.47964
# [498]	validation_0-logloss:0.47956
# [499]	validation_0-logloss:0.47973
# [500]	validation_0-logloss:0.47962
# [501]	validation_0-logloss:0.47963
# [502]	validation_0-logloss:0.47962
# [503]	validation_0-logloss:0.47963
# [504]	validation_0-logloss:0.47973
# [505]	validation_0-logloss:0.47970
# [506]	validation_0-logloss:0.47970
# [507]	validation_0-logloss:0.47976
# [508]	validation_0-logloss:0.47978
# [509]	validation_0-logloss:0.47979
# [510]	validation_0-logloss:0.47980
# [511]	validation_0-logloss:0.47982
# [512]	validation_0-logloss:0.47978
# [513]	validation_0-logloss:0.47979
# [514]	validation_0-logloss:0.47958
# [515]	validation_0-logloss:0.47958
# [516]	validation_0-logloss:0.47950
# [517]	validation_0-logloss:0.47955
# [518]	validation_0-logloss:0.47936
# [519]	validation_0-logloss:0.47939
# [520]	validation_0-logloss:0.47066
# [521]	validation_0-logloss:0.47032
# [522]	validation_0-logloss:0.47026
# [523]	validation_0-logloss:0.47025
# [524]	validation_0-logloss:0.46191
# [525]	validation_0-logloss:0.46194
# [526]	validation_0-logloss:0.46189
# [527]	validation_0-logloss:0.46188
# [528]	validation_0-logloss:0.46176
# [529]	validation_0-logloss:0.46180
# [530]	validation_0-logloss:0.46177
# [531]	validation_0-logloss:0.46170
# [532]	validation_0-logloss:0.46169
# [533]	validation_0-logloss:0.46174
# [534]	validation_0-logloss:0.46159
# [535]	validation_0-logloss:0.46153
# [536]	validation_0-logloss:0.46131
# [537]	validation_0-logloss:0.46129
# [538]	validation_0-logloss:0.46131
# [539]	validation_0-logloss:0.46134
# [540]	validation_0-logloss:0.46134
# [541]	validation_0-logloss:0.46129
# [542]	validation_0-logloss:0.46128
# [543]	validation_0-logloss:0.46125
# [544]	validation_0-logloss:0.46115
# [545]	validation_0-logloss:0.46099
# [546]	validation_0-logloss:0.46084
# [547]	validation_0-logloss:0.46074
# [548]	validation_0-logloss:0.46081
# [549]	validation_0-logloss:0.46080
# [550]	validation_0-logloss:0.46081
# [551]	validation_0-logloss:0.46078
# [552]	validation_0-logloss:0.46081
# [553]	validation_0-logloss:0.46069
# [554]	validation_0-logloss:0.46070
# [555]	validation_0-logloss:0.46074
# [556]	validation_0-logloss:0.46076
# [557]	validation_0-logloss:0.46080
# [558]	validation_0-logloss:0.46093
# [559]	validation_0-logloss:0.46059
# [560]	validation_0-logloss:0.45277
# [561]	validation_0-logloss:0.45279
# [562]	validation_0-logloss:0.45294
# [563]	validation_0-logloss:0.45282
# [564]	validation_0-logloss:0.45287
# [565]	validation_0-logloss:0.45269
# [566]	validation_0-logloss:0.45266
# [567]	validation_0-logloss:0.45266
# [568]	validation_0-logloss:0.45260
# [569]	validation_0-logloss:0.45247
# [570]	validation_0-logloss:0.45249
# [571]	validation_0-logloss:0.45249
# [572]	validation_0-logloss:0.45244
# [573]	validation_0-logloss:0.45248
# [574]	validation_0-logloss:0.45253
# [575]	validation_0-logloss:0.45260
# [576]	validation_0-logloss:0.45249
# [577]	validation_0-logloss:0.45247
# [578]	validation_0-logloss:0.45251
# [579]	validation_0-logloss:0.45251
# [580]	validation_0-logloss:0.45246
# [581]	validation_0-logloss:0.45249
# [582]	validation_0-logloss:0.45254
# [583]	validation_0-logloss:0.45242
# [584]	validation_0-logloss:0.45245
# [585]	validation_0-logloss:0.45249
# [586]	validation_0-logloss:0.45250
# [587]	validation_0-logloss:0.45251
# [588]	validation_0-logloss:0.45242
# [589]	validation_0-logloss:0.45248
# [590]	validation_0-logloss:0.45254
# [591]	validation_0-logloss:0.45250
# [592]	validation_0-logloss:0.45230
# [593]	validation_0-logloss:0.45227
# [594]	validation_0-logloss:0.45230
# [595]	validation_0-logloss:0.45234
# [596]	validation_0-logloss:0.45240
# [597]	validation_0-logloss:0.45235
# [598]	validation_0-logloss:0.45246
# [599]	validation_0-logloss:0.45254
# [600]	validation_0-logloss:0.45243
# [601]	validation_0-logloss:0.45242
# [602]	validation_0-logloss:0.45229
# [603]	validation_0-logloss:0.45220
# [604]	validation_0-logloss:0.45223
# [605]	validation_0-logloss:0.45236
# [606]	validation_0-logloss:0.45228
# [607]	validation_0-logloss:0.45217
# [608]	validation_0-logloss:0.45207
# [609]	validation_0-logloss:0.45207
# [610]	validation_0-logloss:0.45202
# [611]	validation_0-logloss:0.45202
# [612]	validation_0-logloss:0.45202
# [613]	validation_0-logloss:0.45203
# [614]	validation_0-logloss:0.44445
# [615]	validation_0-logloss:0.44453
# [616]	validation_0-logloss:0.44450
# [617]	validation_0-logloss:0.44417
# [618]	validation_0-logloss:0.44414
# [619]	validation_0-logloss:0.44403
# [620]	validation_0-logloss:0.44400
# [621]	validation_0-logloss:0.44402
# [622]	validation_0-logloss:0.44387
# [623]	validation_0-logloss:0.44381
# [624]	validation_0-logloss:0.44374
# [625]	validation_0-logloss:0.44356
# [626]	validation_0-logloss:0.44358
# [627]	validation_0-logloss:0.44361
# [628]	validation_0-logloss:0.44366
# [629]	validation_0-logloss:0.44366
# [630]	validation_0-logloss:0.44382
# [631]	validation_0-logloss:0.44384
# [632]	validation_0-logloss:0.44389
# [633]	validation_0-logloss:0.44394
# [634]	validation_0-logloss:0.44386
# [635]	validation_0-logloss:0.44383
# [636]	validation_0-logloss:0.44375
# [637]	validation_0-logloss:0.44374
# [638]	validation_0-logloss:0.44377
# [639]	validation_0-logloss:0.44353
# [640]	validation_0-logloss:0.44356
# [641]	validation_0-logloss:0.44377
# [642]	validation_0-logloss:0.44373
# [643]	validation_0-logloss:0.44383
# [644]	validation_0-logloss:0.44382
# [645]	validation_0-logloss:0.44375
# [646]	validation_0-logloss:0.44374
# [647]	validation_0-logloss:0.44375
# [648]	validation_0-logloss:0.44369
# [649]	validation_0-logloss:0.44386
# [650]	validation_0-logloss:0.44388
# [651]	validation_0-logloss:0.44397
# [652]	validation_0-logloss:0.44402
# [653]	validation_0-logloss:0.44409
# [654]	validation_0-logloss:0.44413
# [655]	validation_0-logloss:0.44407
# [656]	validation_0-logloss:0.44400
# [657]	validation_0-logloss:0.44387
# [658]	validation_0-logloss:0.44373
# [659]	validation_0-logloss:0.44373
# [660]	validation_0-logloss:0.44372
# [661]	validation_0-logloss:0.44372
# [662]	validation_0-logloss:0.44376
# [663]	validation_0-logloss:0.44399
# [664]	validation_0-logloss:0.44403
# [665]	validation_0-logloss:0.44400
# [666]	validation_0-logloss:0.44395
# [667]	validation_0-logloss:0.44392
# [668]	validation_0-logloss:0.44383
# [669]	validation_0-logloss:0.43663
# [670]	validation_0-logloss:0.43659
# [671]	validation_0-logloss:0.43650
# [672]	validation_0-logloss:0.43640
# [673]	validation_0-logloss:0.43644
# [674]	validation_0-logloss:0.43641
# [675]	validation_0-logloss:0.43643
# [676]	validation_0-logloss:0.43634
# [677]	validation_0-logloss:0.43632
# [678]	validation_0-logloss:0.43631
# [679]	validation_0-logloss:0.43623
# [680]	validation_0-logloss:0.43619
# [681]	validation_0-logloss:0.43625
# [682]	validation_0-logloss:0.43627
# [683]	validation_0-logloss:0.43626
# [684]	validation_0-logloss:0.43633
# [685]	validation_0-logloss:0.43627
# [686]	validation_0-logloss:0.43628
# [687]	validation_0-logloss:0.43623
# [688]	validation_0-logloss:0.43640
# [689]	validation_0-logloss:0.43636
# [690]	validation_0-logloss:0.42962
# [691]	validation_0-logloss:0.42964
# [692]	validation_0-logloss:0.42967
# [693]	validation_0-logloss:0.42967
# [694]	validation_0-logloss:0.42950
# [695]	validation_0-logloss:0.42951
# [696]	validation_0-logloss:0.42947
# [697]	validation_0-logloss:0.42949
# [698]	validation_0-logloss:0.42954
# [699]	validation_0-logloss:0.42953
# [700]	validation_0-logloss:0.42950
# [701]	validation_0-logloss:0.42936
# [702]	validation_0-logloss:0.42929
# [703]	validation_0-logloss:0.42926
# [704]	validation_0-logloss:0.42915
# [705]	validation_0-logloss:0.42919
# [706]	validation_0-logloss:0.42905
# [707]	validation_0-logloss:0.42910
# [708]	validation_0-logloss:0.42904
# [709]	validation_0-logloss:0.42892
# [710]	validation_0-logloss:0.42875
# [711]	validation_0-logloss:0.42879
# [712]	validation_0-logloss:0.42880
# [713]	validation_0-logloss:0.42875
# [714]	validation_0-logloss:0.42900
# [715]	validation_0-logloss:0.42891
# [716]	validation_0-logloss:0.42885
# [717]	validation_0-logloss:0.42877
# [718]	validation_0-logloss:0.42850
# [719]	validation_0-logloss:0.42752
# [720]	validation_0-logloss:0.42753
# [721]	validation_0-logloss:0.42748
# [722]	validation_0-logloss:0.42751
# [723]	validation_0-logloss:0.42752
# [724]	validation_0-logloss:0.42754
# [725]	validation_0-logloss:0.42752
# [726]	validation_0-logloss:0.42756
# [727]	validation_0-logloss:0.42769
# [728]	validation_0-logloss:0.42768
# [729]	validation_0-logloss:0.42766
# [730]	validation_0-logloss:0.42758
# [731]	validation_0-logloss:0.42759
# [732]	validation_0-logloss:0.42754
# [733]	validation_0-logloss:0.42755
# [734]	validation_0-logloss:0.42751
# [735]	validation_0-logloss:0.42763
# [736]	validation_0-logloss:0.42770
# [737]	validation_0-logloss:0.42768
# [738]	validation_0-logloss:0.42766
# [739]	validation_0-logloss:0.42760
# [740]	validation_0-logloss:0.42755
# [741]	validation_0-logloss:0.42755
# [742]	validation_0-logloss:0.42754
# [743]	validation_0-logloss:0.42746
# [744]	validation_0-logloss:0.42750
# [745]	validation_0-logloss:0.42748
# [746]	validation_0-logloss:0.42755
# [747]	validation_0-logloss:0.42750
# [748]	validation_0-logloss:0.42096
# [749]	validation_0-logloss:0.42096
# [750]	validation_0-logloss:0.42095
# [751]	validation_0-logloss:0.42093
# [752]	validation_0-logloss:0.42092
# [753]	validation_0-logloss:0.42094
# [754]	validation_0-logloss:0.42087
# [755]	validation_0-logloss:0.42090
# [756]	validation_0-logloss:0.42092
# [757]	validation_0-logloss:0.42093
# [758]	validation_0-logloss:0.42083
# [759]	validation_0-logloss:0.42074
# [760]	validation_0-logloss:0.42066
# [761]	validation_0-logloss:0.42056
# [762]	validation_0-logloss:0.42059
# [763]	validation_0-logloss:0.42047
# [764]	validation_0-logloss:0.42048
# [765]	validation_0-logloss:0.42051
# [766]	validation_0-logloss:0.42043
# [767]	validation_0-logloss:0.42050
# [768]	validation_0-logloss:0.42048
# [769]	validation_0-logloss:0.42044
# [770]	validation_0-logloss:0.42032
# [771]	validation_0-logloss:0.41442
# [772]	validation_0-logloss:0.41440
# [773]	validation_0-logloss:0.41439
# [774]	validation_0-logloss:0.41439
# [775]	validation_0-logloss:0.41442
# [776]	validation_0-logloss:0.41448
# [777]	validation_0-logloss:0.41433
# [778]	validation_0-logloss:0.40837
# [779]	validation_0-logloss:0.40830
# [780]	validation_0-logloss:0.40838
# [781]	validation_0-logloss:0.40837
# [782]	validation_0-logloss:0.40828
# [783]	validation_0-logloss:0.40826
# [784]	validation_0-logloss:0.40823
# [785]	validation_0-logloss:0.40835
# [786]	validation_0-logloss:0.40845
# [787]	validation_0-logloss:0.40858
# [788]	validation_0-logloss:0.40854
# [789]	validation_0-logloss:0.40854
# [790]	validation_0-logloss:0.40853
# [791]	validation_0-logloss:0.40856
# [792]	validation_0-logloss:0.40841
# [793]	validation_0-logloss:0.40856
# [794]	validation_0-logloss:0.40853
# [795]	validation_0-logloss:0.40856
# [796]	validation_0-logloss:0.40856
# [797]	validation_0-logloss:0.40855
# [798]	validation_0-logloss:0.40859
# [799]	validation_0-logloss:0.40847
#    OOF AUROC: 0.6291
#
# 4️⃣  LightGBM (GBDT variant)...
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's binary_logloss: 0.560588
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's binary_logloss: 0.552362
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's binary_logloss: 0.529463
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's binary_logloss: 0.556721
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's binary_logloss: 0.544851
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's binary_logloss: 0.535916
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's binary_logloss: 0.557909
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's binary_logloss: 0.520567
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's binary_logloss: 0.548176
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [800]	valid_0's binary_logloss: 0.517413
#    OOF AUROC: 0.6324

# %%
# ========================================================================
# STEP 6: ANALYZE DIVERSITY
# ========================================================================
print("\n" + "=" * 80)
print("STEP 6: MODEL DIVERSITY ANALYSIS")
print("=" * 80)

predictions = {
    'CatBoost': oof_cat,
    'LightGBM_DART': oof_lgb,
    'XGBoost': oof_xgb,
    'LightGBM_GBDT': oof_lgb2
}

# Correlation matrix
corr_matrix = pd.DataFrame(predictions).corr()
print("\nPrediction Correlations:")
print(corr_matrix.round(3))

avg_corr = corr_matrix.values[np.triu_indices_from(corr_matrix.values, k=1)].mean()
print(f"\nAverage correlation: {avg_corr:.3f}")

if avg_corr > 0.90:
    print("⚠️  WARNING: Models are too similar!")
else:
    print("✅ Good diversity")
# Out:
# ================================================================================
# STEP 6: MODEL DIVERSITY ANALYSIS
# ================================================================================
#
# Prediction Correlations:
#                CatBoost  LightGBM_DART  XGBoost  LightGBM_GBDT
# CatBoost          1.000          0.950    0.866          0.886
# LightGBM_DART     0.950          1.000    0.859          0.906
# XGBoost           0.866          0.859    1.000          0.844
# LightGBM_GBDT     0.886          0.906    0.844          1.000
#
# Average correlation: 0.885
# ✅ Good diversity

# %%
# ========================================================================
# STEP 7: SMART ENSEMBLING
# ========================================================================
print("\n" + "=" * 80)
print("STEP 7: SMART ENSEMBLING")
print("=" * 80)

# Method 1: Power mean (emphasizes agreement)
def power_mean(predictions, power=2):
    return np.mean([p**power for p in predictions], axis=0)**(1/power)

oof_power = power_mean([oof_cat, oof_lgb, oof_xgb, oof_lgb2], power=2)
test_power = power_mean([test_cat, test_lgb, test_xgb, test_lgb2], power=2)
auc_power = roc_auc_score(y_full, oof_power)

# Method 2: Rank average
from scipy.stats import rankdata
oof_rank = np.mean([rankdata(p) for p in [oof_cat, oof_lgb, oof_xgb, oof_lgb2]], axis=0)
test_rank = np.mean([rankdata(p) for p in [test_cat, test_lgb, test_xgb, test_lgb2]], axis=0)
auc_rank = roc_auc_score(y_full, oof_rank)

# Method 3: Weighted by inverse correlation
weights = 1 / corr_matrix.sum(axis=1)
weights = weights / weights.sum()

oof_weighted = sum(w * p for w, p in zip(weights.values, [oof_cat, oof_lgb, oof_xgb, oof_lgb2]))
test_weighted = sum(w * p for w, p in zip(weights.values, [test_cat, test_lgb, test_xgb, test_lgb2]))
auc_weighted = roc_auc_score(y_full, oof_weighted)

# Method 4: Hill climbing optimization
from scipy.optimize import differential_evolution

def neg_auc_objective(weights):
    weights = np.abs(weights)
    weights = weights / weights.sum()
    pred = sum(w * p for w, p in zip(weights, [oof_cat, oof_lgb, oof_xgb, oof_lgb2]))
    return -roc_auc_score(y_full, pred)

result = differential_evolution(
    neg_auc_objective,
    bounds=[(0, 1)] * 4,
    seed=RANDOM_SEED,
    maxiter=500
)

opt_weights = np.abs(result.x)
opt_weights = opt_weights / opt_weights.sum()

oof_optimized = sum(w * p for w, p in zip(opt_weights, [oof_cat, oof_lgb, oof_xgb, oof_lgb2]))
test_optimized = sum(w * p for w, p in zip(opt_weights, [test_cat, test_lgb, test_xgb, test_lgb2]))
auc_optimized = roc_auc_score(y_full, oof_optimized)

print("\n📊 Ensemble Results:")
print(f"   CatBoost alone:        {auc_cat:.4f}")
print(f"   LightGBM DART alone:   {auc_lgb:.4f}")
print(f"   XGBoost alone:         {auc_xgb:.4f}")
print(f"   LightGBM GBDT alone:   {auc_lgb2:.4f}")
print(f"   Power Mean:            {auc_power:.4f}")
print(f"   Rank Average:          {auc_rank:.4f}")
print(f"   Inverse Corr Weighted: {auc_weighted:.4f}")
print(f"   Optimized Weights:     {auc_optimized:.4f}")

print(f"\nOptimized Weights:")
for name, w in zip(['CatBoost', 'LightGBM_DART', 'XGBoost', 'LightGBM_GBDT'], opt_weights):
    print(f"   {name:20s}: {w:.3f}")
# Out:
# ================================================================================
# STEP 7: SMART ENSEMBLING
# ================================================================================
#
# 📊 Ensemble Results:
#    CatBoost alone:        0.6384
#    LightGBM DART alone:   0.6368
#    XGBoost alone:         0.6291
#    LightGBM GBDT alone:   0.6324
#    Power Mean:            0.6395
#    Rank Average:          0.6392
#    Inverse Corr Weighted: 0.6391
#    Optimized Weights:     0.6401
#
# Optimized Weights:
#    CatBoost            : 0.543
#    LightGBM_DART       : 0.203
#    XGBoost             : 0.050
#    LightGBM_GBDT       : 0.203

# %%
# ========================================================================
# STEP 8: SELECT BEST & CREATE SUBMISSIONS
# ========================================================================
print("\n" + "=" * 80)
print("STEP 8: FINAL SELECTION")
print("=" * 80)

results = {
    'CatBoost': (auc_cat, test_cat),
    'Power Mean': (auc_power, test_power),
    'Rank Average': (auc_rank, test_rank),
    'Inverse Corr Weighted': (auc_weighted, test_weighted),
    'Optimized Weights': (auc_optimized, test_optimized)
}

best_method = max(results, key=lambda x: results[x][0])
best_auc, best_preds = results[best_method]

print(f"\n🏆 Best Method: {best_method}")
print(f"📊 OOF AUROC: {best_auc:.4f}")
print(f"📈 Improvement from 0.6385: {best_auc - 0.6385:+.4f}")

if best_auc >= 0.65:
    print("\n🎉🎉🎉 TARGET REACHED! 🎉🎉🎉")
else:
    print(f"\n📊 Gap to 0.65: {0.65 - best_auc:.4f}")

# Create submissions
test_ids = test[ID_COL] if ID_COL in test.columns else range(len(test))

for method_name, (oof_score, test_preds) in sorted(results.items(), key=lambda x: x[1][0], reverse=True):
    submission = pd.DataFrame({
        'id': test_ids,
        'target': test_preds
    })
    
    filename = f'submission_breakthrough_{method_name.lower().replace(" ", "_")}_{oof_score:.4f}.csv'
    submission.to_csv(filename, index=False)
    print(f"✅ {filename}")

print("\n" + "=" * 80)
print("💡 KEY INSIGHTS")
print("=" * 80)

print(f"\nWhat changed:")
print(f"   • 10-fold CV (was 5) → more reliable OOF")
print(f"   • DART boosting → different learning")
print(f"   • Better features → domain knowledge")
print(f"   • Target encoding → captures patterns")
print(f"   • Optimized ensembling → best combination")

print(f"\n🎯 If still below 0.65:")
print(f"   1. Check Kaggle score vs OOF (should be ±0.003)")
print(f"   2. Try 'Rank Average' (most robust)")
print(f"   3. Consider external data or manual features")
print(f"   4. The 0.65 barrier might require domain expertise")

print("\n" + "=" * 80)
print("✨ PIPELINE COMPLETE ✨")
print("=" * 80)
# Out:
# ================================================================================
# STEP 8: FINAL SELECTION
# ================================================================================
#
# 🏆 Best Method: Optimized Weights
# 📊 OOF AUROC: 0.6401
# 📈 Improvement from 0.6385: +0.0016
#
# 📊 Gap to 0.65: 0.0099
# ✅ submission_breakthrough_optimized_weights_0.6401.csv
# ✅ submission_breakthrough_power_mean_0.6395.csv
# ✅ submission_breakthrough_rank_average_0.6392.csv
# ✅ submission_breakthrough_inverse_corr_weighted_0.6391.csv
# ✅ submission_breakthrough_catboost_0.6384.csv
#
# ================================================================================
# 💡 KEY INSIGHTS
# ================================================================================
#
# What changed:
#    • 10-fold CV (was 5) → more reliable OOF
#    • DART boosting → different learning
#    • Better features → domain knowledge
#    • Target encoding → captures patterns
#    • Optimized ensembling → best combination
#
# 🎯 If still below 0.65:
#    1. Check Kaggle score vs OOF (should be ±0.003)
#    2. Try 'Rank Average' (most robust)
#    3. Consider external data or manual features
#    4. The 0.65 barrier might require domain expertise
#
# ================================================================================
# ✨ PIPELINE COMPLETE ✨
# ================================================================================
